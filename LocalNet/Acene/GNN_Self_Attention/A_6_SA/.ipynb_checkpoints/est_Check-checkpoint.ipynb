# %%
import shutil
import os
import numpy as np
from ipie.analysis.extraction import extract_observable
from ipie.analysis.autocorr import reblock_by_autocorr  # Added for error analysis

# 1. Safely duplicate the file to bypass the active MPI write-lock
original_file = "estimates.0.h5"
temp_file = "estimates_temp.h5"

print(f"Reading active QMC data from {original_file}...\n")

try:
    shutil.copy(original_file, temp_file)
    
    # 2. Use the built-in ipie extractor
    qmc_data = extract_observable(temp_file, "energy")
    
    # 3. Extract the total energy array
    if "ETotal" in qmc_data:
        energies = np.array(qmc_data["ETotal"])
        blocks_done = len(energies)
        
        print(f"--- IPIE PROGRESS REPORT ---")
        print(f"Blocks Completed: {blocks_done} / 200")
        
        if blocks_done > 1:
            # --- THE STATISTICAL ERROR CALCULATION ---
            # reblock_by_autocorr handles the serial correlation between QMC blocks
            df_ac = reblock_by_autocorr(energies, verbose=0)
            
            # Extract the statistically independent mean and error
            mean_energy = float(df_ac["ETotal_ac"].iloc[0])
            error_bar = float(df_ac["ETotal_error_ac"].iloc[0])
            
            print(f"Latest Block:        {energies[-1]:.4f} Ha")
            print(f"Running Average:     {mean_energy:.6f} +/- {error_bar:.6f} Ha")
            
            # Print the last few blocks to see if it's stable
            tail = [round(float(e), 4) for e in energies[-min(200, blocks_done):]]
            print(f"Last 5 Blocks:       {tail}")
            
        elif blocks_done == 1:
            print(f"Current Energy:   {energies[-1]:.4f} Ha")
            print("(Waiting for more blocks to calculate error bars...)")
            
    else:
        print("Data extracted, but 'ETotal' column not found yet. Block 1 might still be running.")

except Exception as e:
    print(f"[!] Error extracting data: {e}")

finally:
    # Clean up the temp file
    if os.path.exists(temp_file):
        os.remove(temp_file)
# Out:
# Reading active QMC data from estimates.0.h5...
#
# --- IPIE PROGRESS REPORT ---
# Blocks Completed: 192 / 200
# Latest Block:        -992.9930 Ha
# Running Average:     -992.952583 +/- 0.042327 Ha
# Last 5 Blocks:       [-991.4574, -991.8849, -992.1551, -992.3306, -992.4506, -992.5326, -992.6169, -992.6448, -992.6885, -992.7145, -992.7429, -992.7606, -992.7687, -992.7762, -992.7817, -992.8064, -992.8302, -992.837, -992.8643, -992.8782, -992.8672, -992.8747, -992.8928, -992.8938, -992.8884, -992.879, -992.8925, -992.9127, -992.9013, -992.8944, -992.9292, -992.915, -992.9037, -992.9193, -992.9517, -992.9646, -992.966, -992.9975, -993.0074, -993.0159, -993.0279, -993.0475, -993.0671, -993.0384, -993.0414, -993.0545, -993.0257, -993.0113, -993.002, -992.9987, -993.036, -993.0272, -993.0355, -993.0193, -993.0374, -992.9925, -992.9948, -993.0242, -993.043, -993.0043, -992.9994, -992.9856, -992.975, -992.9631, -992.9888, -992.9914, -992.9802, -993.0031, -992.964, -992.9762, -992.9748, -992.9801, -992.978, -992.9609, -992.9595, -992.9843, -992.9859, -992.9827, -992.9737, -992.9918, -993.0491, -993.0523, -993.0538, -993.0667, -993.0626, -993.0673, -993.0688, -993.0528, -993.0445, -993.0637, -993.0593, -993.0291, -993.0412, -993.0365, -993.0502, -993.0402, -993.0202, -993.0479, -993.0356, -993.0315, -993.0309, -993.019, -993.0142, -993.024, -993.0284, -993.0289, -993.0009, -993.0288, -993.0308, -993.0139, -993.0004, -992.9948, -992.9828, -992.9726, -992.9821, -992.9935, -993.0229, -993.0051, -992.9944, -993.0226, -993.0215, -993.0222, -993.0173, -993.021, -993.0627, -993.0562, -993.0663, -993.0401, -993.0586, -993.0755, -993.0342, -993.0342, -993.0614, -993.0399, -993.0403, -993.0508, -993.0264, -992.9965, -992.9952, -993.031, -993.0132, -993.0369, -993.0467, -993.0301, -993.0155, -993.0028, -992.9833, -992.9622, -992.9679, -992.9551, -992.932, -992.9557, -992.9769, -992.9751, -992.9506, -992.979, -992.9699, -993.0029, -992.9853, -992.9906, -992.9813, -993.0099, -993.0358, -992.9959, -993.0051, -993.0166, -993.0106, -992.9713, -992.9601, -992.9746, -992.9523, -992.9685, -992.9565, -992.9709, -992.9848, -992.9894, -993.0055, -993.0109, -992.9977, -992.9827, -992.9679, -992.9425, -992.9519, -992.9784, -992.9863, -992.9665, -992.9656, -992.9577, -992.9938, -992.9687, -992.9866, -992.993]
