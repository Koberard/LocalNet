# %%
import numpy as np
import glob
import os
import joblib
import tensorflow as tf
from pyscf import gto, scf
from tensorflow.keras import layers, models, callbacks, optimizers, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# =============================================================================
# 0. CONFIGURATION & DIRECTORY SETUP
# =============================================================================
N_ATOMS = 40 
SYSTEM_NAME = f"H{N_ATOMS}"
CHECKPOINT_PATTERN = f"data_checkpoint_h{N_ATOMS}_run*_rank*_step*.npz" 

DEPLOY_DIR = "deployment_objects"
os.makedirs(DEPLOY_DIR, exist_ok=True)
MODEL_SAVE_NAME  = os.path.join(DEPLOY_DIR, f"NN_{SYSTEM_NAME}_DeltaHF.keras")

print(f">>> STARTING DELTA-LEARNING PIPELINE FOR: {SYSTEM_NAME}")

# =============================================================================
# 1. PHYSICS SETUP & REFERENCE GENERATION
# =============================================================================
print(f"\n>>> 1. Generating Physics Constants & Baseline (HF)...")

mol = gto.M(
    atom=[("H", 0.74 * j, 0, 0) for j in range(N_ATOMS)], 
    basis="sto-6g", verbose=0, spin=0
)
mf = scf.UHF(mol)
mf.kernel()

S = mf.get_ovlp()
eigvals, eigvecs = np.linalg.eigh(S)
S_sqrt = eigvecs @ np.diag(np.sqrt(eigvals)) @ eigvecs.T
S_inv_sqrt = eigvecs @ np.diag(1.0 / np.sqrt(eigvals)) @ eigvecs.T

h_core_ao = mf.get_hcore()
h_core_lowdin = S_inv_sqrt @ h_core_ao @ S_inv_sqrt

# Exact HF Baseline
P_hf_spin = mf.make_rdm1()
P_hf_ao = P_hf_spin[0] + P_hf_spin[1] if P_hf_spin.ndim == 3 else P_hf_spin
# Contravariant transformation for Density Matrix
P_hf_lowdin = S_sqrt @ P_hf_ao @ S_sqrt
E_hf = mf.e_tot

C_sim = mf.mo_coeff[0] 

np.save(os.path.join(DEPLOY_DIR, "S_sqrt.npy"), S_sqrt)
np.save(os.path.join(DEPLOY_DIR, "C_sim.npy"), C_sim)
np.save(os.path.join(DEPLOY_DIR, "h_core_lowdin.npy"), h_core_lowdin)
np.save(os.path.join(DEPLOY_DIR, "P_hf_lowdin.npy"), P_hf_lowdin)
np.save(os.path.join(DEPLOY_DIR, "E_hf.npy"), np.array([E_hf]))

# =============================================================================
# 2. BULLETPROOF CUSTOM LOSS
# =============================================================================
@tf.keras.utils.register_keras_serializable()
def log_cosh_loss(y_true, y_pred):
    """Robust loss with strict shape enforcement to prevent broadcasting bugs."""
    y_true = tf.cast(tf.reshape(y_true, tf.shape(y_pred)), dtype=y_pred.dtype)
    return tf.reduce_mean(tf.math.log(tf.math.cosh(y_pred - y_true)))

# =============================================================================
# 3. LOAD & PROCESS WALKER DATA
# =============================================================================
print(f"\n>>> 3. Loading Walker Checkpoints...")
files = glob.glob(CHECKPOINT_PATTERN)
if not files: raise ValueError("No files found!")

all_GA, all_GB, all_E = [], [], []
nbasis = h_core_ao.shape[0]

for f in sorted(files):
    data = np.load(f)
    all_GA.append(data['GA'])
    all_GB.append(data['GB'])
    all_E.append(data['E'])

GA_raw = np.concatenate(all_GA, axis=0).reshape(-1, nbasis, nbasis)
GB_raw = np.concatenate(all_GB, axis=0).reshape(-1, nbasis, nbasis)
E_raw = np.concatenate(all_E, axis=0).real.reshape(-1)

print("    Transforming Walkers AO -> Lowdin...")
GA_lowdin = np.einsum('ij, bjk, kl -> bil', S_sqrt, GA_raw, S_sqrt)
GB_lowdin = np.einsum('ij, bjk, kl -> bil', S_sqrt, GB_raw, S_sqrt)

# =============================================================================
# 4. PREPARE TRAINING DATA (FIXED SHAPES)
# =============================================================================
print("\n>>> 4. Preparing Physics-Informed Delta Features...")

delta_E_raw = E_raw - E_hf
P_total = GA_lowdin + GB_lowdin
delta_P = P_total - P_hf_lowdin

# Exact 1-Body Delta Energy
E_1B_delta = np.einsum('ij, bji -> b', h_core_lowdin, delta_P).real

# Pure Correlation Residual
y_corr_raw = delta_E_raw - E_1B_delta

median_e = np.median(y_corr_raw)
mad_e = np.median(np.abs(y_corr_raw - median_e))
mask = (y_corr_raw > (median_e - 4 * mad_e)) & (y_corr_raw < (median_e + 4 * mad_e))

delta_P_clean = delta_P[mask]
y_corr_clean  = y_corr_raw[mask]

X_final = np.stack([np.real(delta_P_clean), np.imag(delta_P_clean)], axis=-1)
X_flipped = np.flip(X_final, axis=(1, 2))
y_flipped = y_corr_clean

X_augmented = np.concatenate([X_final, X_flipped], axis=0)
y_augmented = np.concatenate([y_corr_clean, y_flipped], axis=0)

X_train, X_test, y_train, y_test = train_test_split(X_augmented, y_augmented, test_size=0.2, random_state=42)

# STANDARDIZATION (Keeping targets strictly 2D for Keras)
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat  = X_test.reshape(X_test.shape[0], -1)

X_scaler = StandardScaler()
X_train_scaled = X_scaler.fit_transform(X_train_flat).reshape(X_train.shape)
X_test_scaled  = X_scaler.transform(X_test_flat).reshape(X_test.shape)

y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1)) # No flatten()
y_test_scaled  = y_scaler.transform(y_test.reshape(-1, 1))      # No flatten()

joblib.dump(X_scaler, os.path.join(DEPLOY_DIR, "X_scaler.save"))
joblib.dump(y_scaler, os.path.join(DEPLOY_DIR, "y_scaler.save"))

# =============================================================================
# 5. BUILD MLP BOTTLENECK MODEL
# =============================================================================
print("\n>>> 5. Building Regularized Correlation Model...")

def create_correlation_model(input_shape):
    p_in = layers.Input(shape=input_shape)
    x = layers.Flatten()(p_in)
    
    reg = regularizers.l2(1e-4)
    x = layers.Dense(256, activation='swish', kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(128, activation='swish', kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    
    x = layers.Dense(64, activation='swish', kernel_regularizer=reg)(x)
    
    e_corr_scaled = layers.Dense(1, name="Scaled_Corr_Prediction")(x)
    return models.Model(inputs=p_in, outputs=e_corr_scaled)

model = create_correlation_model(input_shape=(X_train.shape[1], X_train.shape[2], 2))
model.compile(loss=log_cosh_loss, optimizer=optimizers.Adamax(learning_rate=1e-3), metrics=['mae'])

history = model.fit(
    X_train_scaled, y_train_scaled,
    validation_data=(X_test_scaled, y_test_scaled),
    epochs=500, batch_size=128, verbose=1,
    callbacks=[
        callbacks.EarlyStopping(patience=40, restore_best_weights=True, monitor='val_loss'),
        callbacks.ReduceLROnPlateau(factor=0.5, patience=15, verbose=1)
    ]
)

# =============================================================================
# 6. EVALUATION
# =============================================================================
print("\n>>> 6. Final Evaluation...")
preds_scaled = model.predict(X_test_scaled)

preds_corr = y_scaler.inverse_transform(preds_scaled).flatten()
y_test_corr = y_scaler.inverse_transform(y_test_scaled).flatten()

mae = np.mean(np.abs(preds_corr - y_test_corr)) * 1000 
print(f"    Test Correlation MAE: {mae:.4f} mHa")

model.save(MODEL_SAVE_NAME)
print(f"    Model saved to {MODEL_SAVE_NAME}")
# Out:
# 2026-02-27 10:41:10.328203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# >>> STARTING DELTA-LEARNING PIPELINE FOR: H40
#
# >>> 1. Generating Physics Constants & Baseline (HF)...
#
# >>> 3. Loading Walker Checkpoints...
#     Transforming Walkers AO -> Lowdin...
#
# >>> 4. Preparing Physics-Informed Delta Features...
#
# >>> 5. Building Regularized Correlation Model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772207851.457482 1628714 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43608 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:23:00.0, compute capability: 8.6
# Epoch 1/500
# 2026-02-27 10:57:34.556274: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f9678002b30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-27 10:57:34.556319: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA A40, Compute Capability 8.6
# 2026-02-27 10:57:34.617834: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-27 10:57:34.801500: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2026-02-27 10:57:34.963217: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:34.963241: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:34.963255: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:34.963273: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:34.963333: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:34.963347: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:43.504344: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1500', 124 bytes spill stores, 124 bytes spill loads
#
# 2026-02-27 10:57:47.618706: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1587', 64 bytes spill stores, 64 bytes spill loads
#
# 2026-02-27 10:57:47.802601: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1705', 64 bytes spill stores, 64 bytes spill loads
#  68/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5912 - mae: 0.9559
# I0000 00:00:1772207871.399722 1630496 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 411/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3664 - mae: 0.6595
# 2026-02-27 10:57:52.667675: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:52.667722: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:52.667755: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:57:54.451923: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_962', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-02-27 10:57:57.655255: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1072', 28 bytes spill stores, 28 bytes spill loads
#
# 2026-02-27 10:57:58.525205: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1072', 24 bytes spill stores, 24 bytes spill loads
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3610 - mae: 0.6519
# 2026-02-27 10:58:03.709873: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:58:03.709926: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 10:58:06.030236: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_98', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-02-27 10:58:08.777776: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_98', 4 bytes spill stores, 4 bytes spill loads
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - loss: 0.3608 - mae: 0.6516 - val_loss: 0.1757 - val_mae: 0.3587 - learning_rate: 0.0010
# Epoch 2/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1834 - mae: 0.3836 - val_loss: 0.1490 - val_mae: 0.3091 - learning_rate: 0.0010
# Epoch 3/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1523 - mae: 0.3253 - val_loss: 0.1222 - val_mae: 0.2510 - learning_rate: 0.0010
# Epoch 4/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1364 - mae: 0.2955 - val_loss: 0.1204 - val_mae: 0.2500 - learning_rate: 0.0010
# Epoch 5/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1240 - mae: 0.2736 - val_loss: 0.1006 - val_mae: 0.2098 - learning_rate: 0.0010
# Epoch 6/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1139 - mae: 0.2582 - val_loss: 0.0913 - val_mae: 0.1973 - learning_rate: 0.0010
# Epoch 7/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1042 - mae: 0.2446 - val_loss: 0.0872 - val_mae: 0.1948 - learning_rate: 0.0010
# Epoch 8/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0959 - mae: 0.2349 - val_loss: 0.0803 - val_mae: 0.1911 - learning_rate: 0.0010
# Epoch 9/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0892 - mae: 0.2298 - val_loss: 0.0749 - val_mae: 0.1877 - learning_rate: 0.0010
# Epoch 10/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0837 - mae: 0.2259 - val_loss: 0.0655 - val_mae: 0.1711 - learning_rate: 0.0010
# Epoch 11/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0776 - mae: 0.2203 - val_loss: 0.0627 - val_mae: 0.1728 - learning_rate: 0.0010
# Epoch 12/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0733 - mae: 0.2176 - val_loss: 0.0566 - val_mae: 0.1628 - learning_rate: 0.0010
# Epoch 13/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0694 - mae: 0.2158 - val_loss: 0.0549 - val_mae: 0.1715 - learning_rate: 0.0010
# Epoch 14/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0657 - mae: 0.2132 - val_loss: 0.0530 - val_mae: 0.1669 - learning_rate: 0.0010
# Epoch 15/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0616 - mae: 0.2072 - val_loss: 0.0521 - val_mae: 0.1721 - learning_rate: 0.0010
# Epoch 16/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0591 - mae: 0.2066 - val_loss: 0.0440 - val_mae: 0.1496 - learning_rate: 0.0010
# Epoch 17/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0568 - mae: 0.2049 - val_loss: 0.0427 - val_mae: 0.1513 - learning_rate: 0.0010
# Epoch 18/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0545 - mae: 0.2022 - val_loss: 0.0441 - val_mae: 0.1611 - learning_rate: 0.0010
# Epoch 19/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0527 - mae: 0.2000 - val_loss: 0.0431 - val_mae: 0.1665 - learning_rate: 0.0010
# Epoch 20/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0521 - mae: 0.2025 - val_loss: 0.0439 - val_mae: 0.1652 - learning_rate: 0.0010
# Epoch 21/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0505 - mae: 0.1999 - val_loss: 0.0369 - val_mae: 0.1476 - learning_rate: 0.0010
# Epoch 22/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0494 - mae: 0.1996 - val_loss: 0.0355 - val_mae: 0.1460 - learning_rate: 0.0010
# Epoch 23/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0479 - mae: 0.1976 - val_loss: 0.0389 - val_mae: 0.1601 - learning_rate: 0.0010
# Epoch 24/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0462 - mae: 0.1933 - val_loss: 0.0356 - val_mae: 0.1547 - learning_rate: 0.0010
# Epoch 25/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0470 - mae: 0.1982 - val_loss: 0.0332 - val_mae: 0.1450 - learning_rate: 0.0010
# Epoch 26/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0475 - mae: 0.2021 - val_loss: 0.0336 - val_mae: 0.1472 - learning_rate: 0.0010
# Epoch 27/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0455 - mae: 0.1958 - val_loss: 0.0329 - val_mae: 0.1454 - learning_rate: 0.0010
# Epoch 28/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0445 - mae: 0.1956 - val_loss: 0.0311 - val_mae: 0.1385 - learning_rate: 0.0010
# Epoch 29/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0441 - mae: 0.1945 - val_loss: 0.0335 - val_mae: 0.1535 - learning_rate: 0.0010
# Epoch 30/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0448 - mae: 0.1979 - val_loss: 0.0289 - val_mae: 0.1331 - learning_rate: 0.0010
# Epoch 31/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0435 - mae: 0.1950 - val_loss: 0.0334 - val_mae: 0.1538 - learning_rate: 0.0010
# Epoch 32/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0430 - mae: 0.1939 - val_loss: 0.0316 - val_mae: 0.1462 - learning_rate: 0.0010
# Epoch 33/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0424 - mae: 0.1927 - val_loss: 0.0294 - val_mae: 0.1395 - learning_rate: 0.0010
# Epoch 34/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0413 - mae: 0.1901 - val_loss: 0.0291 - val_mae: 0.1396 - learning_rate: 0.0010
# Epoch 35/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0409 - mae: 0.1899 - val_loss: 0.0285 - val_mae: 0.1372 - learning_rate: 0.0010
# Epoch 36/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0412 - mae: 0.1909 - val_loss: 0.0290 - val_mae: 0.1371 - learning_rate: 0.0010
# Epoch 37/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0408 - mae: 0.1896 - val_loss: 0.0289 - val_mae: 0.1388 - learning_rate: 0.0010
# Epoch 38/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0401 - mae: 0.1874 - val_loss: 0.0281 - val_mae: 0.1368 - learning_rate: 0.0010
# Epoch 39/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0413 - mae: 0.1930 - val_loss: 0.0291 - val_mae: 0.1412 - learning_rate: 0.0010
# Epoch 40/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0407 - mae: 0.1903 - val_loss: 0.0284 - val_mae: 0.1374 - learning_rate: 0.0010
# Epoch 41/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0398 - mae: 0.1879 - val_loss: 0.0276 - val_mae: 0.1342 - learning_rate: 0.0010
# Epoch 42/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0392 - mae: 0.1872 - val_loss: 0.0267 - val_mae: 0.1322 - learning_rate: 0.0010
# Epoch 43/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0400 - mae: 0.1901 - val_loss: 0.0291 - val_mae: 0.1467 - learning_rate: 0.0010
# Epoch 44/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0391 - mae: 0.1868 - val_loss: 0.0279 - val_mae: 0.1376 - learning_rate: 0.0010
# Epoch 45/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0386 - mae: 0.1861 - val_loss: 0.0269 - val_mae: 0.1355 - learning_rate: 0.0010
# Epoch 46/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0370 - mae: 0.1814 - val_loss: 0.0267 - val_mae: 0.1365 - learning_rate: 0.0010
# Epoch 47/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0377 - mae: 0.1842 - val_loss: 0.0266 - val_mae: 0.1334 - learning_rate: 0.0010
# Epoch 48/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0384 - mae: 0.1861 - val_loss: 0.0270 - val_mae: 0.1379 - learning_rate: 0.0010
# Epoch 49/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0379 - mae: 0.1845 - val_loss: 0.0277 - val_mae: 0.1463 - learning_rate: 0.0010
# Epoch 50/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0384 - mae: 0.1868 - val_loss: 0.0286 - val_mae: 0.1465 - learning_rate: 0.0010
# Epoch 51/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0376 - mae: 0.1840 - val_loss: 0.0256 - val_mae: 0.1323 - learning_rate: 0.0010
# Epoch 52/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0379 - mae: 0.1855 - val_loss: 0.0271 - val_mae: 0.1405 - learning_rate: 0.0010
# Epoch 53/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0389 - mae: 0.1892 - val_loss: 0.0266 - val_mae: 0.1343 - learning_rate: 0.0010
# Epoch 54/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0376 - mae: 0.1836 - val_loss: 0.0261 - val_mae: 0.1355 - learning_rate: 0.0010
# Epoch 55/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0378 - mae: 0.1850 - val_loss: 0.0257 - val_mae: 0.1318 - learning_rate: 0.0010
# Epoch 56/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0376 - mae: 0.1841 - val_loss: 0.0262 - val_mae: 0.1324 - learning_rate: 0.0010
# Epoch 57/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0367 - mae: 0.1812 - val_loss: 0.0277 - val_mae: 0.1469 - learning_rate: 0.0010
# Epoch 58/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0372 - mae: 0.1836 - val_loss: 0.0247 - val_mae: 0.1304 - learning_rate: 0.0010
# Epoch 59/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0361 - mae: 0.1795 - val_loss: 0.0246 - val_mae: 0.1307 - learning_rate: 0.0010
# Epoch 60/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0358 - mae: 0.1787 - val_loss: 0.0256 - val_mae: 0.1330 - learning_rate: 0.0010
# Epoch 61/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0366 - mae: 0.1805 - val_loss: 0.0264 - val_mae: 0.1352 - learning_rate: 0.0010
# Epoch 62/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0369 - mae: 0.1822 - val_loss: 0.0247 - val_mae: 0.1261 - learning_rate: 0.0010
# Epoch 63/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0361 - mae: 0.1792 - val_loss: 0.0268 - val_mae: 0.1401 - learning_rate: 0.0010
# Epoch 64/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0374 - mae: 0.1839 - val_loss: 0.0255 - val_mae: 0.1336 - learning_rate: 0.0010
# Epoch 65/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0365 - mae: 0.1801 - val_loss: 0.0264 - val_mae: 0.1363 - learning_rate: 0.0010
# Epoch 66/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0363 - mae: 0.1797 - val_loss: 0.0278 - val_mae: 0.1470 - learning_rate: 0.0010
# Epoch 67/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0361 - mae: 0.1796 - val_loss: 0.0254 - val_mae: 0.1303 - learning_rate: 0.0010
# Epoch 68/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0363 - mae: 0.1799 - val_loss: 0.0254 - val_mae: 0.1289 - learning_rate: 0.0010
# Epoch 69/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0362 - mae: 0.1796 - val_loss: 0.0254 - val_mae: 0.1323 - learning_rate: 0.0010
# Epoch 70/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0358 - mae: 0.1785 - val_loss: 0.0250 - val_mae: 0.1301 - learning_rate: 0.0010
# Epoch 71/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0361 - mae: 0.1809 - val_loss: 0.0250 - val_mae: 0.1290 - learning_rate: 0.0010
# Epoch 72/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0352 - mae: 0.1762 - val_loss: 0.0254 - val_mae: 0.1351 - learning_rate: 0.0010
# Epoch 73/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0356 - mae: 0.1783 - val_loss: 0.0255 - val_mae: 0.1337 - learning_rate: 0.0010
# Epoch 74/500
# 419/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0358 - mae: 0.1783
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0358 - mae: 0.1783 - val_loss: 0.0257 - val_mae: 0.1328 - learning_rate: 0.0010
# Epoch 75/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0335 - mae: 0.1718 - val_loss: 0.0214 - val_mae: 0.1158 - learning_rate: 5.0000e-04
# Epoch 76/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0312 - mae: 0.1651 - val_loss: 0.0218 - val_mae: 0.1226 - learning_rate: 5.0000e-04
# Epoch 77/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0305 - mae: 0.1642 - val_loss: 0.0201 - val_mae: 0.1163 - learning_rate: 5.0000e-04
# Epoch 78/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0289 - mae: 0.1592 - val_loss: 0.0182 - val_mae: 0.1049 - learning_rate: 5.0000e-04
# Epoch 79/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0290 - mae: 0.1613 - val_loss: 0.0192 - val_mae: 0.1135 - learning_rate: 5.0000e-04
# Epoch 80/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0281 - mae: 0.1591 - val_loss: 0.0187 - val_mae: 0.1124 - learning_rate: 5.0000e-04
# Epoch 81/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0280 - mae: 0.1587 - val_loss: 0.0191 - val_mae: 0.1171 - learning_rate: 5.0000e-04
# Epoch 82/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0277 - mae: 0.1594 - val_loss: 0.0195 - val_mae: 0.1207 - learning_rate: 5.0000e-04
# Epoch 83/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0270 - mae: 0.1566 - val_loss: 0.0185 - val_mae: 0.1148 - learning_rate: 5.0000e-04
# Epoch 84/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0274 - mae: 0.1584 - val_loss: 0.0187 - val_mae: 0.1150 - learning_rate: 5.0000e-04
# Epoch 85/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0267 - mae: 0.1567 - val_loss: 0.0170 - val_mae: 0.1060 - learning_rate: 5.0000e-04
# Epoch 86/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0271 - mae: 0.1582 - val_loss: 0.0172 - val_mae: 0.1086 - learning_rate: 5.0000e-04
# Epoch 87/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0266 - mae: 0.1567 - val_loss: 0.0171 - val_mae: 0.1081 - learning_rate: 5.0000e-04
# Epoch 88/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0264 - mae: 0.1568 - val_loss: 0.0174 - val_mae: 0.1105 - learning_rate: 5.0000e-04
# Epoch 89/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0269 - mae: 0.1585 - val_loss: 0.0180 - val_mae: 0.1158 - learning_rate: 5.0000e-04
# Epoch 90/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0265 - mae: 0.1574 - val_loss: 0.0190 - val_mae: 0.1207 - learning_rate: 5.0000e-04
# Epoch 91/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0274 - mae: 0.1605 - val_loss: 0.0171 - val_mae: 0.1086 - learning_rate: 5.0000e-04
# Epoch 92/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0264 - mae: 0.1569 - val_loss: 0.0177 - val_mae: 0.1147 - learning_rate: 5.0000e-04
# Epoch 93/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0274 - mae: 0.1613 - val_loss: 0.0185 - val_mae: 0.1180 - learning_rate: 5.0000e-04
# Epoch 94/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0260 - mae: 0.1556 - val_loss: 0.0177 - val_mae: 0.1145 - learning_rate: 5.0000e-04
# Epoch 95/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0268 - mae: 0.1585 - val_loss: 0.0184 - val_mae: 0.1205 - learning_rate: 5.0000e-04
# Epoch 96/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0266 - mae: 0.1575 - val_loss: 0.0178 - val_mae: 0.1146 - learning_rate: 5.0000e-04
# Epoch 97/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0268 - mae: 0.1588 - val_loss: 0.0175 - val_mae: 0.1106 - learning_rate: 5.0000e-04
# Epoch 98/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0263 - mae: 0.1572 - val_loss: 0.0173 - val_mae: 0.1135 - learning_rate: 5.0000e-04
# Epoch 99/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0269 - mae: 0.1596 - val_loss: 0.0183 - val_mae: 0.1199 - learning_rate: 5.0000e-04
# Epoch 100/500
# 418/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - mae: 0.1590
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0266 - mae: 0.1590 - val_loss: 0.0171 - val_mae: 0.1096 - learning_rate: 5.0000e-04
# Epoch 101/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0253 - mae: 0.1536 - val_loss: 0.0158 - val_mae: 0.1063 - learning_rate: 2.5000e-04
# Epoch 102/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0233 - mae: 0.1460 - val_loss: 0.0150 - val_mae: 0.1016 - learning_rate: 2.5000e-04
# Epoch 103/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0241 - mae: 0.1499 - val_loss: 0.0149 - val_mae: 0.1009 - learning_rate: 2.5000e-04
# Epoch 104/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0233 - mae: 0.1478 - val_loss: 0.0140 - val_mae: 0.0969 - learning_rate: 2.5000e-04
# Epoch 105/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0232 - mae: 0.1471 - val_loss: 0.0148 - val_mae: 0.1032 - learning_rate: 2.5000e-04
# Epoch 106/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0227 - mae: 0.1462 - val_loss: 0.0142 - val_mae: 0.0987 - learning_rate: 2.5000e-04
# Epoch 107/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0227 - mae: 0.1464 - val_loss: 0.0144 - val_mae: 0.1031 - learning_rate: 2.5000e-04
# Epoch 108/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0230 - mae: 0.1481 - val_loss: 0.0138 - val_mae: 0.0984 - learning_rate: 2.5000e-04
# Epoch 109/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0219 - mae: 0.1436 - val_loss: 0.0139 - val_mae: 0.1003 - learning_rate: 2.5000e-04
# Epoch 110/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0214 - mae: 0.1423 - val_loss: 0.0133 - val_mae: 0.0969 - learning_rate: 2.5000e-04
# Epoch 111/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0228 - mae: 0.1476 - val_loss: 0.0143 - val_mae: 0.1028 - learning_rate: 2.5000e-04
# Epoch 112/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0221 - mae: 0.1460 - val_loss: 0.0139 - val_mae: 0.1024 - learning_rate: 2.5000e-04
# Epoch 113/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0218 - mae: 0.1442 - val_loss: 0.0134 - val_mae: 0.0973 - learning_rate: 2.5000e-04
# Epoch 114/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0223 - mae: 0.1473 - val_loss: 0.0133 - val_mae: 0.0984 - learning_rate: 2.5000e-04
# Epoch 115/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0226 - mae: 0.1486 - val_loss: 0.0129 - val_mae: 0.0951 - learning_rate: 2.5000e-04
# Epoch 116/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0206 - mae: 0.1394 - val_loss: 0.0136 - val_mae: 0.1011 - learning_rate: 2.5000e-04
# Epoch 117/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0214 - mae: 0.1438 - val_loss: 0.0134 - val_mae: 0.1000 - learning_rate: 2.5000e-04
# Epoch 118/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0210 - mae: 0.1417 - val_loss: 0.0135 - val_mae: 0.1006 - learning_rate: 2.5000e-04
# Epoch 119/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0213 - mae: 0.1436 - val_loss: 0.0135 - val_mae: 0.0999 - learning_rate: 2.5000e-04
# Epoch 120/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0216 - mae: 0.1451 - val_loss: 0.0133 - val_mae: 0.1006 - learning_rate: 2.5000e-04
# Epoch 121/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0215 - mae: 0.1454 - val_loss: 0.0140 - val_mae: 0.1055 - learning_rate: 2.5000e-04
# Epoch 122/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0213 - mae: 0.1438 - val_loss: 0.0133 - val_mae: 0.1015 - learning_rate: 2.5000e-04
# Epoch 123/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0211 - mae: 0.1430 - val_loss: 0.0126 - val_mae: 0.0962 - learning_rate: 2.5000e-04
# Epoch 124/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0210 - mae: 0.1425 - val_loss: 0.0127 - val_mae: 0.0955 - learning_rate: 2.5000e-04
# Epoch 125/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - mae: 0.1420 - val_loss: 0.0124 - val_mae: 0.0951 - learning_rate: 2.5000e-04
# Epoch 126/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0208 - mae: 0.1423 - val_loss: 0.0132 - val_mae: 0.1019 - learning_rate: 2.5000e-04
# Epoch 127/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0216 - mae: 0.1462 - val_loss: 0.0125 - val_mae: 0.0961 - learning_rate: 2.5000e-04
# Epoch 128/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0219 - mae: 0.1477 - val_loss: 0.0130 - val_mae: 0.0979 - learning_rate: 2.5000e-04
# Epoch 129/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0209 - mae: 0.1430 - val_loss: 0.0134 - val_mae: 0.1026 - learning_rate: 2.5000e-04
# Epoch 130/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0210 - mae: 0.1434 - val_loss: 0.0140 - val_mae: 0.1068 - learning_rate: 2.5000e-04
# Epoch 131/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0207 - mae: 0.1429 - val_loss: 0.0129 - val_mae: 0.0996 - learning_rate: 2.5000e-04
# Epoch 132/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - mae: 0.1423 - val_loss: 0.0130 - val_mae: 0.1000 - learning_rate: 2.5000e-04
# Epoch 133/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0212 - mae: 0.1449 - val_loss: 0.0143 - val_mae: 0.1085 - learning_rate: 2.5000e-04
# Epoch 134/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0211 - mae: 0.1440 - val_loss: 0.0132 - val_mae: 0.1023 - learning_rate: 2.5000e-04
# Epoch 135/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0209 - mae: 0.1436 - val_loss: 0.0126 - val_mae: 0.0968 - learning_rate: 2.5000e-04
# Epoch 136/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0204 - mae: 0.1413 - val_loss: 0.0132 - val_mae: 0.1025 - learning_rate: 2.5000e-04
# Epoch 137/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0215 - mae: 0.1466 - val_loss: 0.0129 - val_mae: 0.0996 - learning_rate: 2.5000e-04
# Epoch 138/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0211 - mae: 0.1447 - val_loss: 0.0132 - val_mae: 0.1029 - learning_rate: 2.5000e-04
# Epoch 139/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0210 - mae: 0.1440 - val_loss: 0.0131 - val_mae: 0.1006 - learning_rate: 2.5000e-04
# Epoch 140/500
# 415/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0209 - mae: 0.1443
# Epoch 140: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0209 - mae: 0.1443 - val_loss: 0.0125 - val_mae: 0.0982 - learning_rate: 2.5000e-04
# Epoch 141/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0196 - mae: 0.1386 - val_loss: 0.0112 - val_mae: 0.0902 - learning_rate: 1.2500e-04
# Epoch 142/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0194 - mae: 0.1379 - val_loss: 0.0113 - val_mae: 0.0913 - learning_rate: 1.2500e-04
# Epoch 143/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0192 - mae: 0.1373 - val_loss: 0.0117 - val_mae: 0.0945 - learning_rate: 1.2500e-04
# Epoch 144/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0190 - mae: 0.1366 - val_loss: 0.0111 - val_mae: 0.0899 - learning_rate: 1.2500e-04
# Epoch 145/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0193 - mae: 0.1383 - val_loss: 0.0114 - val_mae: 0.0932 - learning_rate: 1.2500e-04
# Epoch 146/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0189 - mae: 0.1361 - val_loss: 0.0108 - val_mae: 0.0888 - learning_rate: 1.2500e-04
# Epoch 147/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0189 - mae: 0.1364 - val_loss: 0.0106 - val_mae: 0.0864 - learning_rate: 1.2500e-04
# Epoch 148/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0191 - mae: 0.1376 - val_loss: 0.0114 - val_mae: 0.0942 - learning_rate: 1.2500e-04
# Epoch 149/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0195 - mae: 0.1397 - val_loss: 0.0109 - val_mae: 0.0897 - learning_rate: 1.2500e-04
# Epoch 150/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0188 - mae: 0.1363 - val_loss: 0.0111 - val_mae: 0.0925 - learning_rate: 1.2500e-04
# Epoch 151/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0193 - mae: 0.1383 - val_loss: 0.0108 - val_mae: 0.0895 - learning_rate: 1.2500e-04
# Epoch 152/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0192 - mae: 0.1383 - val_loss: 0.0105 - val_mae: 0.0870 - learning_rate: 1.2500e-04
# Epoch 153/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - mae: 0.1354 - val_loss: 0.0115 - val_mae: 0.0952 - learning_rate: 1.2500e-04
# Epoch 154/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0188 - mae: 0.1372 - val_loss: 0.0109 - val_mae: 0.0909 - learning_rate: 1.2500e-04
# Epoch 155/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0187 - mae: 0.1363 - val_loss: 0.0107 - val_mae: 0.0886 - learning_rate: 1.2500e-04
# Epoch 156/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0179 - mae: 0.1336 - val_loss: 0.0107 - val_mae: 0.0900 - learning_rate: 1.2500e-04
# Epoch 157/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0182 - mae: 0.1350 - val_loss: 0.0104 - val_mae: 0.0885 - learning_rate: 1.2500e-04
# Epoch 158/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - mae: 0.1350 - val_loss: 0.0104 - val_mae: 0.0878 - learning_rate: 1.2500e-04
# Epoch 159/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0182 - mae: 0.1355 - val_loss: 0.0112 - val_mae: 0.0943 - learning_rate: 1.2500e-04
# Epoch 160/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0181 - mae: 0.1350 - val_loss: 0.0104 - val_mae: 0.0882 - learning_rate: 1.2500e-04
# Epoch 161/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0188 - mae: 0.1382 - val_loss: 0.0101 - val_mae: 0.0860 - learning_rate: 1.2500e-04
# Epoch 162/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0188 - mae: 0.1379 - val_loss: 0.0107 - val_mae: 0.0916 - learning_rate: 1.2500e-04
# Epoch 163/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0186 - mae: 0.1365 - val_loss: 0.0105 - val_mae: 0.0887 - learning_rate: 1.2500e-04
# Epoch 164/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0184 - mae: 0.1363 - val_loss: 0.0109 - val_mae: 0.0935 - learning_rate: 1.2500e-04
# Epoch 165/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0180 - mae: 0.1347 - val_loss: 0.0108 - val_mae: 0.0923 - learning_rate: 1.2500e-04
# Epoch 166/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0190 - mae: 0.1393 - val_loss: 0.0105 - val_mae: 0.0904 - learning_rate: 1.2500e-04
# Epoch 167/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0189 - mae: 0.1390 - val_loss: 0.0103 - val_mae: 0.0890 - learning_rate: 1.2500e-04
# Epoch 168/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0182 - mae: 0.1363 - val_loss: 0.0100 - val_mae: 0.0863 - learning_rate: 1.2500e-04
# Epoch 169/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0171 - mae: 0.1307 - val_loss: 0.0101 - val_mae: 0.0874 - learning_rate: 1.2500e-04
# Epoch 170/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0181 - mae: 0.1351 - val_loss: 0.0101 - val_mae: 0.0869 - learning_rate: 1.2500e-04
# Epoch 171/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - mae: 0.1364 - val_loss: 0.0103 - val_mae: 0.0886 - learning_rate: 1.2500e-04
# Epoch 172/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0178 - mae: 0.1343 - val_loss: 0.0103 - val_mae: 0.0900 - learning_rate: 1.2500e-04
# Epoch 173/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0182 - mae: 0.1364 - val_loss: 0.0100 - val_mae: 0.0871 - learning_rate: 1.2500e-04
# Epoch 174/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - mae: 0.1369 - val_loss: 0.0103 - val_mae: 0.0887 - learning_rate: 1.2500e-04
# Epoch 175/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - mae: 0.1368 - val_loss: 0.0103 - val_mae: 0.0900 - learning_rate: 1.2500e-04
# Epoch 176/500
# 419/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - mae: 0.1382
# Epoch 176: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0186 - mae: 0.1380 - val_loss: 0.0104 - val_mae: 0.0908 - learning_rate: 1.2500e-04
# Epoch 177/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0174 - mae: 0.1327 - val_loss: 0.0096 - val_mae: 0.0851 - learning_rate: 6.2500e-05
# Epoch 178/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0178 - mae: 0.1345 - val_loss: 0.0094 - val_mae: 0.0834 - learning_rate: 6.2500e-05
# Epoch 179/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0173 - mae: 0.1330 - val_loss: 0.0097 - val_mae: 0.0857 - learning_rate: 6.2500e-05
# Epoch 180/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0167 - mae: 0.1294 - val_loss: 0.0095 - val_mae: 0.0841 - learning_rate: 6.2500e-05
# Epoch 181/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0170 - mae: 0.1315 - val_loss: 0.0093 - val_mae: 0.0829 - learning_rate: 6.2500e-05
# Epoch 182/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0169 - mae: 0.1305 - val_loss: 0.0091 - val_mae: 0.0811 - learning_rate: 6.2500e-05
# Epoch 183/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0165 - mae: 0.1287 - val_loss: 0.0093 - val_mae: 0.0826 - learning_rate: 6.2500e-05
# Epoch 184/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0164 - mae: 0.1286 - val_loss: 0.0094 - val_mae: 0.0843 - learning_rate: 6.2500e-05
# Epoch 185/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - mae: 0.1320 - val_loss: 0.0094 - val_mae: 0.0844 - learning_rate: 6.2500e-05
# Epoch 186/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0164 - mae: 0.1295 - val_loss: 0.0093 - val_mae: 0.0838 - learning_rate: 6.2500e-05
# Epoch 187/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0164 - mae: 0.1286 - val_loss: 0.0090 - val_mae: 0.0813 - learning_rate: 6.2500e-05
# Epoch 188/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0167 - mae: 0.1305 - val_loss: 0.0089 - val_mae: 0.0811 - learning_rate: 6.2500e-05
# Epoch 189/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0175 - mae: 0.1348 - val_loss: 0.0092 - val_mae: 0.0833 - learning_rate: 6.2500e-05
# Epoch 190/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0174 - mae: 0.1339 - val_loss: 0.0092 - val_mae: 0.0836 - learning_rate: 6.2500e-05
# Epoch 191/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0169 - mae: 0.1313 - val_loss: 0.0087 - val_mae: 0.0789 - learning_rate: 6.2500e-05
# Epoch 192/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0167 - mae: 0.1303 - val_loss: 0.0091 - val_mae: 0.0829 - learning_rate: 6.2500e-05
# Epoch 193/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0169 - mae: 0.1310 - val_loss: 0.0093 - val_mae: 0.0845 - learning_rate: 6.2500e-05
# Epoch 194/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0169 - mae: 0.1320 - val_loss: 0.0088 - val_mae: 0.0806 - learning_rate: 6.2500e-05
# Epoch 195/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0158 - mae: 0.1255 - val_loss: 0.0090 - val_mae: 0.0821 - learning_rate: 6.2500e-05
# Epoch 196/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0165 - mae: 0.1304 - val_loss: 0.0087 - val_mae: 0.0790 - learning_rate: 6.2500e-05
# Epoch 197/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0170 - mae: 0.1323 - val_loss: 0.0089 - val_mae: 0.0819 - learning_rate: 6.2500e-05
# Epoch 198/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0174 - mae: 0.1349 - val_loss: 0.0088 - val_mae: 0.0802 - learning_rate: 6.2500e-05
# Epoch 199/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0166 - mae: 0.1303 - val_loss: 0.0087 - val_mae: 0.0795 - learning_rate: 6.2500e-05
# Epoch 200/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0170 - mae: 0.1327 - val_loss: 0.0090 - val_mae: 0.0819 - learning_rate: 6.2500e-05
# Epoch 201/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0165 - mae: 0.1299 - val_loss: 0.0091 - val_mae: 0.0832 - learning_rate: 6.2500e-05
# Epoch 202/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0166 - mae: 0.1307 - val_loss: 0.0089 - val_mae: 0.0817 - learning_rate: 6.2500e-05
# Epoch 203/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0166 - mae: 0.1308 - val_loss: 0.0087 - val_mae: 0.0790 - learning_rate: 6.2500e-05
# Epoch 204/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0165 - mae: 0.1305 - val_loss: 0.0093 - val_mae: 0.0856 - learning_rate: 6.2500e-05
# Epoch 205/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - mae: 0.1332 - val_loss: 0.0092 - val_mae: 0.0840 - learning_rate: 6.2500e-05
# Epoch 206/500
# 413/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - mae: 0.1297
# Epoch 206: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0164 - mae: 0.1297 - val_loss: 0.0087 - val_mae: 0.0808 - learning_rate: 6.2500e-05
# Epoch 207/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0158 - mae: 0.1268 - val_loss: 0.0083 - val_mae: 0.0777 - learning_rate: 3.1250e-05
# Epoch 208/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0160 - mae: 0.1281 - val_loss: 0.0084 - val_mae: 0.0788 - learning_rate: 3.1250e-05
# Epoch 209/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0165 - mae: 0.1307 - val_loss: 0.0084 - val_mae: 0.0788 - learning_rate: 3.1250e-05
# Epoch 210/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0158 - mae: 0.1274 - val_loss: 0.0083 - val_mae: 0.0780 - learning_rate: 3.1250e-05
# Epoch 211/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0158 - mae: 0.1265 - val_loss: 0.0084 - val_mae: 0.0782 - learning_rate: 3.1250e-05
# Epoch 212/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mae: 0.1265 - val_loss: 0.0082 - val_mae: 0.0771 - learning_rate: 3.1250e-05
# Epoch 213/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0157 - mae: 0.1276 - val_loss: 0.0082 - val_mae: 0.0779 - learning_rate: 3.1250e-05
# Epoch 214/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1273 - val_loss: 0.0083 - val_mae: 0.0785 - learning_rate: 3.1250e-05
# Epoch 215/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0159 - mae: 0.1274 - val_loss: 0.0084 - val_mae: 0.0789 - learning_rate: 3.1250e-05
# Epoch 216/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mae: 0.1271 - val_loss: 0.0083 - val_mae: 0.0782 - learning_rate: 3.1250e-05
# Epoch 217/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1273 - val_loss: 0.0085 - val_mae: 0.0795 - learning_rate: 3.1250e-05
# Epoch 218/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1250 - val_loss: 0.0081 - val_mae: 0.0771 - learning_rate: 3.1250e-05
# Epoch 219/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0158 - mae: 0.1277 - val_loss: 0.0083 - val_mae: 0.0784 - learning_rate: 3.1250e-05
# Epoch 220/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1269 - val_loss: 0.0082 - val_mae: 0.0775 - learning_rate: 3.1250e-05
# Epoch 221/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0155 - mae: 0.1267 - val_loss: 0.0083 - val_mae: 0.0786 - learning_rate: 3.1250e-05
# Epoch 222/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0152 - mae: 0.1249 - val_loss: 0.0085 - val_mae: 0.0807 - learning_rate: 3.1250e-05
# Epoch 223/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1270 - val_loss: 0.0081 - val_mae: 0.0767 - learning_rate: 3.1250e-05
# Epoch 224/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - mae: 0.1241 - val_loss: 0.0083 - val_mae: 0.0785 - learning_rate: 3.1250e-05
# Epoch 225/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mae: 0.1275 - val_loss: 0.0081 - val_mae: 0.0770 - learning_rate: 3.1250e-05
# Epoch 226/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0154 - mae: 0.1262 - val_loss: 0.0082 - val_mae: 0.0780 - learning_rate: 3.1250e-05
# Epoch 227/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0161 - mae: 0.1292 - val_loss: 0.0082 - val_mae: 0.0785 - learning_rate: 3.1250e-05
# Epoch 228/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0152 - mae: 0.1246 - val_loss: 0.0082 - val_mae: 0.0785 - learning_rate: 3.1250e-05
# Epoch 229/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0158 - mae: 0.1275 - val_loss: 0.0082 - val_mae: 0.0781 - learning_rate: 3.1250e-05
# Epoch 230/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0162 - mae: 0.1299 - val_loss: 0.0083 - val_mae: 0.0793 - learning_rate: 3.1250e-05
# Epoch 231/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0162 - mae: 0.1303 - val_loss: 0.0082 - val_mae: 0.0782 - learning_rate: 3.1250e-05
# Epoch 232/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1243 - val_loss: 0.0082 - val_mae: 0.0783 - learning_rate: 3.1250e-05
# Epoch 233/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0162 - mae: 0.1304 - val_loss: 0.0082 - val_mae: 0.0780 - learning_rate: 3.1250e-05
# Epoch 234/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0158 - mae: 0.1278 - val_loss: 0.0082 - val_mae: 0.0786 - learning_rate: 3.1250e-05
# Epoch 235/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1261 - val_loss: 0.0081 - val_mae: 0.0779 - learning_rate: 3.1250e-05
# Epoch 236/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0161 - mae: 0.1299 - val_loss: 0.0079 - val_mae: 0.0762 - learning_rate: 3.1250e-05
# Epoch 237/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0155 - mae: 0.1269 - val_loss: 0.0081 - val_mae: 0.0778 - learning_rate: 3.1250e-05
# Epoch 238/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0151 - mae: 0.1250 - val_loss: 0.0080 - val_mae: 0.0763 - learning_rate: 3.1250e-05
# Epoch 239/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0155 - mae: 0.1269 - val_loss: 0.0080 - val_mae: 0.0770 - learning_rate: 3.1250e-05
# Epoch 240/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0154 - mae: 0.1260 - val_loss: 0.0080 - val_mae: 0.0768 - learning_rate: 3.1250e-05
# Epoch 241/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mae: 0.1276 - val_loss: 0.0083 - val_mae: 0.0797 - learning_rate: 3.1250e-05
# Epoch 242/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1260 - val_loss: 0.0079 - val_mae: 0.0760 - learning_rate: 3.1250e-05
# Epoch 243/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1258 - val_loss: 0.0082 - val_mae: 0.0789 - learning_rate: 3.1250e-05
# Epoch 244/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1244 - val_loss: 0.0080 - val_mae: 0.0771 - learning_rate: 3.1250e-05
# Epoch 245/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0155 - mae: 0.1269 - val_loss: 0.0079 - val_mae: 0.0752 - learning_rate: 3.1250e-05
# Epoch 246/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0154 - mae: 0.1259 - val_loss: 0.0080 - val_mae: 0.0771 - learning_rate: 3.1250e-05
# Epoch 247/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0152 - mae: 0.1251 - val_loss: 0.0081 - val_mae: 0.0782 - learning_rate: 3.1250e-05
# Epoch 248/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1223 - val_loss: 0.0081 - val_mae: 0.0776 - learning_rate: 3.1250e-05
# Epoch 249/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1267 - val_loss: 0.0080 - val_mae: 0.0773 - learning_rate: 3.1250e-05
# Epoch 250/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1283 - val_loss: 0.0082 - val_mae: 0.0790 - learning_rate: 3.1250e-05
# Epoch 251/500
# 415/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156 - mae: 0.1274
# Epoch 251: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0156 - mae: 0.1274 - val_loss: 0.0079 - val_mae: 0.0768 - learning_rate: 3.1250e-05
# Epoch 252/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1259 - val_loss: 0.0078 - val_mae: 0.0761 - learning_rate: 1.5625e-05
# Epoch 253/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mae: 0.1277 - val_loss: 0.0077 - val_mae: 0.0749 - learning_rate: 1.5625e-05
# Epoch 254/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - mae: 0.1247 - val_loss: 0.0077 - val_mae: 0.0757 - learning_rate: 1.5625e-05
# Epoch 255/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0149 - mae: 0.1241 - val_loss: 0.0077 - val_mae: 0.0752 - learning_rate: 1.5625e-05
# Epoch 256/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0150 - mae: 0.1249 - val_loss: 0.0077 - val_mae: 0.0755 - learning_rate: 1.5625e-05
# Epoch 257/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0152 - mae: 0.1255 - val_loss: 0.0076 - val_mae: 0.0745 - learning_rate: 1.5625e-05
# Epoch 258/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0151 - mae: 0.1252 - val_loss: 0.0078 - val_mae: 0.0760 - learning_rate: 1.5625e-05
# Epoch 259/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0155 - mae: 0.1268 - val_loss: 0.0077 - val_mae: 0.0756 - learning_rate: 1.5625e-05
# Epoch 260/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0154 - mae: 0.1270 - val_loss: 0.0078 - val_mae: 0.0762 - learning_rate: 1.5625e-05
# Epoch 261/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0159 - mae: 0.1291 - val_loss: 0.0077 - val_mae: 0.0755 - learning_rate: 1.5625e-05
# Epoch 262/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1246 - val_loss: 0.0076 - val_mae: 0.0745 - learning_rate: 1.5625e-05
# Epoch 263/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0155 - mae: 0.1275 - val_loss: 0.0077 - val_mae: 0.0752 - learning_rate: 1.5625e-05
# Epoch 264/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1241 - val_loss: 0.0077 - val_mae: 0.0759 - learning_rate: 1.5625e-05
# Epoch 265/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0146 - mae: 0.1230 - val_loss: 0.0077 - val_mae: 0.0752 - learning_rate: 1.5625e-05
# Epoch 266/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0151 - mae: 0.1253 - val_loss: 0.0076 - val_mae: 0.0745 - learning_rate: 1.5625e-05
# Epoch 267/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0152 - mae: 0.1256 - val_loss: 0.0076 - val_mae: 0.0747 - learning_rate: 1.5625e-05
# Epoch 268/500
# 417/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0157 - mae: 0.1284
# Epoch 268: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1283 - val_loss: 0.0077 - val_mae: 0.0755 - learning_rate: 1.5625e-05
# Epoch 269/500
# ...
# Epoch 341/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1249 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 4.8828e-07
# Epoch 342/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0155 - mae: 0.1283 - val_loss: 0.0074 - val_mae: 0.0735 - learning_rate: 4.8828e-07
# Epoch 343/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0149 - mae: 0.1242 - val_loss: 0.0074 - val_mae: 0.0737 - learning_rate: 4.8828e-07
# Epoch 344/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0141 - mae: 0.1204 - val_loss: 0.0073 - val_mae: 0.0723 - learning_rate: 4.8828e-07
# Epoch 345/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1243 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 4.8828e-07
# Epoch 346/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1243 - val_loss: 0.0074 - val_mae: 0.0737 - learning_rate: 4.8828e-07
# Epoch 347/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1295 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 4.8828e-07
# Epoch 348/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1221 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 4.8828e-07
# Epoch 349/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0143 - mae: 0.1227 - val_loss: 0.0074 - val_mae: 0.0732 - learning_rate: 4.8828e-07
# Epoch 350/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0148 - mae: 0.1242 - val_loss: 0.0074 - val_mae: 0.0731 - learning_rate: 4.8828e-07
# Epoch 351/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0140 - mae: 0.1204 - val_loss: 0.0074 - val_mae: 0.0742 - learning_rate: 4.8828e-07
# Epoch 352/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1237 - val_loss: 0.0073 - val_mae: 0.0733 - learning_rate: 4.8828e-07
# Epoch 353/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1237 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 4.8828e-07
# Epoch 354/500
# 422/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149 - mae: 0.1246
# Epoch 354: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0149 - mae: 0.1246 - val_loss: 0.0074 - val_mae: 0.0738 - learning_rate: 4.8828e-07
# Epoch 355/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1252 - val_loss: 0.0074 - val_mae: 0.0734 - learning_rate: 2.4414e-07
# Epoch 356/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0149 - mae: 0.1246 - val_loss: 0.0073 - val_mae: 0.0731 - learning_rate: 2.4414e-07
# Epoch 357/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0151 - mae: 0.1265 - val_loss: 0.0074 - val_mae: 0.0738 - learning_rate: 2.4414e-07
# Epoch 358/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0152 - mae: 0.1261 - val_loss: 0.0075 - val_mae: 0.0742 - learning_rate: 2.4414e-07
# Epoch 359/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1263 - val_loss: 0.0074 - val_mae: 0.0732 - learning_rate: 2.4414e-07
# Epoch 360/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1238 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 2.4414e-07
# Epoch 361/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1224 - val_loss: 0.0074 - val_mae: 0.0733 - learning_rate: 2.4414e-07
# Epoch 362/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - mae: 0.1253 - val_loss: 0.0072 - val_mae: 0.0721 - learning_rate: 2.4414e-07
# Epoch 363/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0152 - mae: 0.1267 - val_loss: 0.0073 - val_mae: 0.0730 - learning_rate: 2.4414e-07
# Epoch 364/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1233 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 2.4414e-07
# Epoch 365/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1253 - val_loss: 0.0073 - val_mae: 0.0730 - learning_rate: 2.4414e-07
# Epoch 366/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1234 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 2.4414e-07
# Epoch 367/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0156 - mae: 0.1279 - val_loss: 0.0073 - val_mae: 0.0732 - learning_rate: 2.4414e-07
# Epoch 368/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1247 - val_loss: 0.0073 - val_mae: 0.0727 - learning_rate: 2.4414e-07
# Epoch 369/500
# 432/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0147 - mae: 0.1240
# Epoch 369: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1240 - val_loss: 0.0074 - val_mae: 0.0738 - learning_rate: 2.4414e-07
# Epoch 370/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1219 - val_loss: 0.0073 - val_mae: 0.0731 - learning_rate: 1.2207e-07
# Epoch 371/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1228 - val_loss: 0.0074 - val_mae: 0.0734 - learning_rate: 1.2207e-07
# Epoch 372/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1233 - val_loss: 0.0073 - val_mae: 0.0723 - learning_rate: 1.2207e-07
# Epoch 373/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - mae: 0.1258 - val_loss: 0.0073 - val_mae: 0.0724 - learning_rate: 1.2207e-07
# Epoch 374/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1236 - val_loss: 0.0073 - val_mae: 0.0726 - learning_rate: 1.2207e-07
# Epoch 375/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0153 - mae: 0.1275 - val_loss: 0.0073 - val_mae: 0.0727 - learning_rate: 1.2207e-07
# Epoch 376/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0146 - mae: 0.1236 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 1.2207e-07
# Epoch 377/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0150 - mae: 0.1252 - val_loss: 0.0074 - val_mae: 0.0730 - learning_rate: 1.2207e-07
# Epoch 378/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0147 - mae: 0.1240 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 1.2207e-07
# Epoch 379/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mae: 0.1287 - val_loss: 0.0074 - val_mae: 0.0731 - learning_rate: 1.2207e-07
# Epoch 380/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0143 - mae: 0.1223 - val_loss: 0.0073 - val_mae: 0.0723 - learning_rate: 1.2207e-07
# Epoch 381/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0142 - mae: 0.1217 - val_loss: 0.0074 - val_mae: 0.0741 - learning_rate: 1.2207e-07
# Epoch 382/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1235 - val_loss: 0.0074 - val_mae: 0.0742 - learning_rate: 1.2207e-07
# Epoch 383/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1253 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 1.2207e-07
# Epoch 384/500
# 413/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144 - mae: 0.1228
# Epoch 384: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1228 - val_loss: 0.0074 - val_mae: 0.0735 - learning_rate: 1.2207e-07
# Epoch 385/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1236 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 6.1035e-08
# Epoch 386/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1224 - val_loss: 0.0074 - val_mae: 0.0732 - learning_rate: 6.1035e-08
# Epoch 387/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1246 - val_loss: 0.0074 - val_mae: 0.0738 - learning_rate: 6.1035e-08
# Epoch 388/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1236 - val_loss: 0.0074 - val_mae: 0.0733 - learning_rate: 6.1035e-08
# Epoch 389/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0143 - mae: 0.1218 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 6.1035e-08
# Epoch 390/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0156 - mae: 0.1284 - val_loss: 0.0073 - val_mae: 0.0723 - learning_rate: 6.1035e-08
# Epoch 391/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1243 - val_loss: 0.0074 - val_mae: 0.0734 - learning_rate: 6.1035e-08
# Epoch 392/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1238 - val_loss: 0.0072 - val_mae: 0.0719 - learning_rate: 6.1035e-08
# Epoch 393/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1233 - val_loss: 0.0074 - val_mae: 0.0736 - learning_rate: 6.1035e-08
# Epoch 394/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0147 - mae: 0.1238 - val_loss: 0.0073 - val_mae: 0.0726 - learning_rate: 6.1035e-08
# Epoch 395/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0145 - mae: 0.1230 - val_loss: 0.0074 - val_mae: 0.0736 - learning_rate: 6.1035e-08
# Epoch 396/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0149 - mae: 0.1257 - val_loss: 0.0074 - val_mae: 0.0742 - learning_rate: 6.1035e-08
# Epoch 397/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144 - mae: 0.1224 - val_loss: 0.0074 - val_mae: 0.0734 - learning_rate: 6.1035e-08
# Epoch 398/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0152 - mae: 0.1269 - val_loss: 0.0074 - val_mae: 0.0743 - learning_rate: 6.1035e-08
# Epoch 399/500
# 415/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0154 - mae: 0.1271
# Epoch 399: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1271 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 6.1035e-08
# Epoch 400/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0147 - mae: 0.1232 - val_loss: 0.0075 - val_mae: 0.0748 - learning_rate: 3.0518e-08
# Epoch 401/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0149 - mae: 0.1252 - val_loss: 0.0074 - val_mae: 0.0733 - learning_rate: 3.0518e-08
# Epoch 402/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1233 - val_loss: 0.0073 - val_mae: 0.0726 - learning_rate: 3.0518e-08
# Epoch 403/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1242 - val_loss: 0.0074 - val_mae: 0.0732 - learning_rate: 3.0518e-08
# Epoch 404/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1236 - val_loss: 0.0074 - val_mae: 0.0731 - learning_rate: 3.0518e-08
# Epoch 405/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0149 - mae: 0.1255 - val_loss: 0.0073 - val_mae: 0.0725 - learning_rate: 3.0518e-08
# Epoch 406/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1233 - val_loss: 0.0075 - val_mae: 0.0743 - learning_rate: 3.0518e-08
# Epoch 407/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - mae: 0.1260 - val_loss: 0.0073 - val_mae: 0.0722 - learning_rate: 3.0518e-08
# Epoch 408/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1237 - val_loss: 0.0074 - val_mae: 0.0735 - learning_rate: 3.0518e-08
# Epoch 409/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0153 - mae: 0.1278 - val_loss: 0.0073 - val_mae: 0.0730 - learning_rate: 3.0518e-08
# Epoch 410/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0145 - mae: 0.1221 - val_loss: 0.0073 - val_mae: 0.0722 - learning_rate: 3.0518e-08
# Epoch 411/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0149 - mae: 0.1249 - val_loss: 0.0074 - val_mae: 0.0731 - learning_rate: 3.0518e-08
# Epoch 412/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0145 - mae: 0.1225 - val_loss: 0.0073 - val_mae: 0.0724 - learning_rate: 3.0518e-08
# Epoch 413/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0152 - mae: 0.1256 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 3.0518e-08
# Epoch 414/500
# 421/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156 - mae: 0.1283
# Epoch 414: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0156 - mae: 0.1282 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 3.0518e-08
# Epoch 415/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0145 - mae: 0.1223 - val_loss: 0.0073 - val_mae: 0.0726 - learning_rate: 1.5259e-08
# Epoch 416/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0147 - mae: 0.1242 - val_loss: 0.0074 - val_mae: 0.0735 - learning_rate: 1.5259e-08
# Epoch 417/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0148 - mae: 0.1242 - val_loss: 0.0075 - val_mae: 0.0747 - learning_rate: 1.5259e-08
# Epoch 418/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1246 - val_loss: 0.0074 - val_mae: 0.0740 - learning_rate: 1.5259e-08
# Epoch 419/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0150 - mae: 0.1245 - val_loss: 0.0073 - val_mae: 0.0719 - learning_rate: 1.5259e-08
# Epoch 420/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0142 - mae: 0.1213 - val_loss: 0.0074 - val_mae: 0.0740 - learning_rate: 1.5259e-08
# Epoch 421/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0154 - mae: 0.1275 - val_loss: 0.0073 - val_mae: 0.0729 - learning_rate: 1.5259e-08
# Epoch 422/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1245 - val_loss: 0.0074 - val_mae: 0.0742 - learning_rate: 1.5259e-08
# Epoch 423/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0150 - mae: 0.1256 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 1.5259e-08
# Epoch 424/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0145 - mae: 0.1230 - val_loss: 0.0074 - val_mae: 0.0738 - learning_rate: 1.5259e-08
# Epoch 425/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0150 - mae: 0.1258 - val_loss: 0.0074 - val_mae: 0.0740 - learning_rate: 1.5259e-08
# Epoch 426/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0146 - mae: 0.1232 - val_loss: 0.0073 - val_mae: 0.0731 - learning_rate: 1.5259e-08
# Epoch 427/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0147 - mae: 0.1236 - val_loss: 0.0073 - val_mae: 0.0734 - learning_rate: 1.5259e-08
# Epoch 428/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0143 - mae: 0.1226 - val_loss: 0.0073 - val_mae: 0.0726 - learning_rate: 1.5259e-08
# Epoch 429/500
# 421/435 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0148 - mae: 0.1251
# Epoch 429: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1250 - val_loss: 0.0073 - val_mae: 0.0732 - learning_rate: 1.5259e-08
# Epoch 430/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0148 - mae: 0.1243 - val_loss: 0.0073 - val_mae: 0.0732 - learning_rate: 7.6294e-09
# Epoch 431/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0145 - mae: 0.1232 - val_loss: 0.0073 - val_mae: 0.0728 - learning_rate: 7.6294e-09
# Epoch 432/500
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0144 - mae: 0.1223 - val_loss: 0.0072 - val_mae: 0.0721 - learning_rate: 7.6294e-09
#
# >>> 6. Final Evaluation...
# 2026-02-27 11:09:40.840775: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 11:09:40.840821: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-27 11:09:42.713821: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_47', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-02-27 11:09:45.709379: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_60', 24 bytes spill stores, 24 bytes spill loads
# 435/435 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step
#     Test Correlation MAE: 11.4412 mHa
#     Model saved to deployment_objects/NN_H40_DeltaHF.keras
