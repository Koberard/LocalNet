# %%
import numpy as np
import glob
import os
import joblib
import tensorflow as tf
from pyscf import gto, scf
from tensorflow.keras import layers, models, callbacks, optimizers, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# =============================================================================
# 0. CONFIGURATION & DIRECTORY SETUP
# =============================================================================
N_ATOMS = 110 
SYSTEM_NAME = f"H{N_ATOMS}"
CHECKPOINT_PATTERN = f"data_checkpoint_h{N_ATOMS}_run*_rank*_step*.npz" 

DEPLOY_DIR = "deployment_objects"
os.makedirs(DEPLOY_DIR, exist_ok=True)
MODEL_SAVE_NAME  = os.path.join(DEPLOY_DIR, f"NN_{SYSTEM_NAME}_DeltaHF.keras")

print(f">>> STARTING DELTA-LEARNING PIPELINE FOR: {SYSTEM_NAME}")

# =============================================================================
# 1. PHYSICS SETUP & REFERENCE GENERATION
# =============================================================================
print(f"\n>>> 1. Generating Physics Constants & Baseline (HF)...")

mol = gto.M(
    atom=[("H", 0.74 * j, 0, 0) for j in range(N_ATOMS)], 
    basis="sto-6g", verbose=0, spin=0
)
mf = scf.UHF(mol)
mf.kernel()

S = mf.get_ovlp()
eigvals, eigvecs = np.linalg.eigh(S)
S_sqrt = eigvecs @ np.diag(np.sqrt(eigvals)) @ eigvecs.T
S_inv_sqrt = eigvecs @ np.diag(1.0 / np.sqrt(eigvals)) @ eigvecs.T

h_core_ao = mf.get_hcore()
h_core_lowdin = S_inv_sqrt @ h_core_ao @ S_inv_sqrt

# Exact HF Baseline
P_hf_spin = mf.make_rdm1()
P_hf_ao = P_hf_spin[0] + P_hf_spin[1] if P_hf_spin.ndim == 3 else P_hf_spin
# Contravariant transformation for Density Matrix
P_hf_lowdin = S_sqrt @ P_hf_ao @ S_sqrt
E_hf = mf.e_tot

C_sim = mf.mo_coeff[0] 

np.save(os.path.join(DEPLOY_DIR, "S_sqrt.npy"), S_sqrt)
np.save(os.path.join(DEPLOY_DIR, "C_sim.npy"), C_sim)
np.save(os.path.join(DEPLOY_DIR, "h_core_lowdin.npy"), h_core_lowdin)
np.save(os.path.join(DEPLOY_DIR, "P_hf_lowdin.npy"), P_hf_lowdin)
np.save(os.path.join(DEPLOY_DIR, "E_hf.npy"), np.array([E_hf]))

# =============================================================================
# 2. BULLETPROOF CUSTOM LOSS
# =============================================================================
@tf.keras.utils.register_keras_serializable()
def log_cosh_loss(y_true, y_pred):
    """Robust loss with strict shape enforcement to prevent broadcasting bugs."""
    y_true = tf.cast(tf.reshape(y_true, tf.shape(y_pred)), dtype=y_pred.dtype)
    return tf.reduce_mean(tf.math.log(tf.math.cosh(y_pred - y_true)))

# =============================================================================
# 3. LOAD & PROCESS WALKER DATA (ACCELERATED)
# =============================================================================
print(f"\n>>> 3. Loading Walker Checkpoints in Parallel...")
files = sorted(glob.glob(CHECKPOINT_PATTERN))
if not files: raise ValueError("No files found!")

nbasis = h_core_ao.shape[0]

# Helper function for parallel loading
def load_checkpoint(f):
    with np.load(f) as data:
        # Extracting immediately to close the file handler
        return data['GA'], data['GB'], data['E']

# 1. Parallelize I/O using all available CPU cores
# This bypasses the sequential wait time of reading .npz files
results = joblib.Parallel(n_jobs=-1)(joblib.delayed(load_checkpoint)(f) for f in files)

# Unpack results into continuous arrays
GA_raw = np.concatenate([r[0] for r in results], axis=0).reshape(-1, nbasis, nbasis)
GB_raw = np.concatenate([r[1] for r in results], axis=0).reshape(-1, nbasis, nbasis)
E_raw  = np.concatenate([r[2] for r in results], axis=0).real.reshape(-1)

# Free up memory before heavy matrix math
del results

print("    Transforming Walkers AO -> Lowdin (BLAS Accelerated)...")
# 2. Swap einsum for batched matrix multiplication (@)
# NumPy broadcasts the `@` operator over the batch dimension using multi-threaded BLAS
GA_lowdin = S_sqrt @ GA_raw @ S_sqrt
GB_lowdin = S_sqrt @ GB_raw @ S_sqrt

# =============================================================================
# 4. PREPARE TRAINING DATA (FIXED SHAPES)
# =============================================================================
print("\n>>> 4. Preparing Physics-Informed Delta Features...")

delta_E_raw = E_raw - E_hf
P_total = GA_lowdin + GB_lowdin
delta_P = P_total - P_hf_lowdin

# Exact 1-Body Delta Energy
E_1B_delta = np.einsum('ij, bji -> b', h_core_lowdin, delta_P).real

# Pure Correlation Residual
y_corr_raw = delta_E_raw - E_1B_delta

median_e = np.median(y_corr_raw)
mad_e = np.median(np.abs(y_corr_raw - median_e))
mask = (y_corr_raw > (median_e - 4 * mad_e)) & (y_corr_raw < (median_e + 4 * mad_e))

delta_P_clean = delta_P[mask]
y_corr_clean  = y_corr_raw[mask]

X_final = np.stack([np.real(delta_P_clean), np.imag(delta_P_clean)], axis=-1)
X_flipped = np.flip(X_final, axis=(1, 2))
y_flipped = y_corr_clean

X_augmented = np.concatenate([X_final, X_flipped], axis=0)
y_augmented = np.concatenate([y_corr_clean, y_flipped], axis=0)

X_train, X_test, y_train, y_test = train_test_split(X_augmented, y_augmented, test_size=0.2, random_state=42)

# STANDARDIZATION (Keeping targets strictly 2D for Keras)
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat  = X_test.reshape(X_test.shape[0], -1)

X_scaler = StandardScaler()
X_train_scaled = X_scaler.fit_transform(X_train_flat).reshape(X_train.shape)
X_test_scaled  = X_scaler.transform(X_test_flat).reshape(X_test.shape)

y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1)) # No flatten()
y_test_scaled  = y_scaler.transform(y_test.reshape(-1, 1))      # No flatten()

joblib.dump(X_scaler, os.path.join(DEPLOY_DIR, "X_scaler.save"))
joblib.dump(y_scaler, os.path.join(DEPLOY_DIR, "y_scaler.save"))

# =============================================================================
# 5. BUILD MLP BOTTLENECK MODEL
# =============================================================================
print("\n>>> 5. Building Regularized Correlation Model...")

def create_correlation_model(input_shape):
    p_in = layers.Input(shape=input_shape)
    x = layers.Flatten()(p_in)
    
    reg = regularizers.l2(1e-4)
    x = layers.Dense(256, activation='swish', kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(128, activation='swish', kernel_regularizer=reg)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    
    x = layers.Dense(64, activation='swish', kernel_regularizer=reg)(x)
    
    e_corr_scaled = layers.Dense(1, name="Scaled_Corr_Prediction")(x)
    return models.Model(inputs=p_in, outputs=e_corr_scaled)

model = create_correlation_model(input_shape=(X_train.shape[1], X_train.shape[2], 2))
model.compile(loss=log_cosh_loss, optimizer=optimizers.Adamax(learning_rate=1e-3), metrics=['mae'])

history = model.fit(
    X_train_scaled, y_train_scaled,
    validation_data=(X_test_scaled, y_test_scaled),
    epochs=1000, batch_size=128, verbose=1,
    callbacks=[
        callbacks.EarlyStopping(patience=40, restore_best_weights=True, monitor='val_loss'),
        callbacks.ReduceLROnPlateau(factor=0.5, patience=15, verbose=1)
    ]
)

# =============================================================================
# 6. EVALUATION
# =============================================================================
print("\n>>> 6. Final Evaluation...")
preds_scaled = model.predict(X_test_scaled)

preds_corr = y_scaler.inverse_transform(preds_scaled).flatten()
y_test_corr = y_scaler.inverse_transform(y_test_scaled).flatten()

mae = np.mean(np.abs(preds_corr - y_test_corr)) * 1000 
print(f"    Test Correlation MAE: {mae:.4f} mHa")

model.save(MODEL_SAVE_NAME)
print(f"    Model saved to {MODEL_SAVE_NAME}")
# Out:
# 2026-03-02 11:20:31.198450: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# >>> STARTING DELTA-LEARNING PIPELINE FOR: H110
#
# >>> 1. Generating Physics Constants & Baseline (HF)...
#
# >>> 3. Loading Walker Checkpoints in Parallel...
#     Transforming Walkers AO -> Lowdin (BLAS Accelerated)...
#
# >>> 4. Preparing Physics-Informed Delta Features...
#
# >>> 5. Building Regularized Correlation Model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772468680.562704 2050339 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43608 MB memory:  -> device: 0, name: NVIDIA A40, pci bus id: 0000:23:00.0, compute capability: 8.6
# 2026-03-02 11:26:10.947176: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 5293604800 exceeds 10% of free system memory.
# 2026-03-02 11:26:17.627975: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 5293604800 exceeds 10% of free system memory.
# Epoch 1/1000
# 2026-03-02 11:26:22.398399: I external/local_xla/xla/service/service.cc:163] XLA service 0x7ef9b80060f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-02 11:26:22.398439: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA A40, Compute Capability 8.6
# 2026-03-02 11:26:22.460941: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-02 11:26:22.657687: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2026-03-02 11:26:22.824166: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:22.824191: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:22.824206: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:22.824224: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:22.824286: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:22.824299: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:23.039888: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_210', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-03-02 11:26:30.260441: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1494', 124 bytes spill stores, 124 bytes spill loads
#
# 2026-03-02 11:26:32.501899: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1730', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-03-02 11:26:34.851373: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1581', 64 bytes spill stores, 64 bytes spill loads
#
# 2026-03-02 11:26:35.807711: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1699', 64 bytes spill stores, 64 bytes spill loads
#  40/428 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6771 - mae: 1.0610
# I0000 00:00:1772468799.383943 2051313 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 423/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3963 - mae: 0.6960
# 2026-03-02 11:26:41.394546: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:41.394588: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:41.394623: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:42.027894: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_210', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-03-02 11:26:44.009709: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_962', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-03-02 11:26:46.340876: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1072', 28 bytes spill stores, 28 bytes spill loads
#
# 2026-03-02 11:26:46.354428: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1072', 24 bytes spill stores, 24 bytes spill loads
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3952 - mae: 0.6945
# 2026-03-02 11:26:52.164523: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 1323449600 exceeds 10% of free system memory.
# 2026-03-02 11:26:52.681329: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 1323449600 exceeds 10% of free system memory.
# 2026-03-02 11:26:54.014981: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:54.015025: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:26:56.916274: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_98', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-03-02 11:26:58.928811: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_98', 16 bytes spill stores, 16 bytes spill loads
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - loss: 0.3950 - mae: 0.6942 - val_loss: 0.1898 - val_mae: 0.3734 - learning_rate: 0.0010
# Epoch 2/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - loss: 0.2141 - mae: 0.4257 - val_loss: 0.1644 - val_mae: 0.3228 - learning_rate: 0.0010
# Epoch 3/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1814 - mae: 0.3664 - val_loss: 0.1437 - val_mae: 0.2843 - learning_rate: 0.0010
# Epoch 4/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1610 - mae: 0.3298 - val_loss: 0.1364 - val_mae: 0.2792 - learning_rate: 0.0010
# Epoch 5/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1479 - mae: 0.3102 - val_loss: 0.1264 - val_mae: 0.2637 - learning_rate: 0.0010
# Epoch 6/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1395 - mae: 0.3016 - val_loss: 0.1227 - val_mae: 0.2647 - learning_rate: 0.0010
# Epoch 7/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1305 - mae: 0.2914 - val_loss: 0.1165 - val_mae: 0.2613 - learning_rate: 0.0010
# Epoch 8/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1240 - mae: 0.2877 - val_loss: 0.1092 - val_mae: 0.2556 - learning_rate: 0.0010
# Epoch 9/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1169 - mae: 0.2806 - val_loss: 0.1086 - val_mae: 0.2625 - learning_rate: 0.0010
# Epoch 10/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1121 - mae: 0.2782 - val_loss: 0.1013 - val_mae: 0.2513 - learning_rate: 0.0010
# Epoch 11/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1087 - mae: 0.2758 - val_loss: 0.1026 - val_mae: 0.2611 - learning_rate: 0.0010
# Epoch 12/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1049 - mae: 0.2720 - val_loss: 0.0975 - val_mae: 0.2531 - learning_rate: 0.0010
# Epoch 13/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1032 - mae: 0.2723 - val_loss: 0.0958 - val_mae: 0.2536 - learning_rate: 0.0010
# Epoch 14/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1008 - mae: 0.2708 - val_loss: 0.0926 - val_mae: 0.2472 - learning_rate: 0.0010
# Epoch 15/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0992 - mae: 0.2692 - val_loss: 0.0887 - val_mae: 0.2403 - learning_rate: 0.0010
# Epoch 16/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0973 - mae: 0.2680 - val_loss: 0.0880 - val_mae: 0.2410 - learning_rate: 0.0010
# Epoch 17/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0958 - mae: 0.2658 - val_loss: 0.0871 - val_mae: 0.2413 - learning_rate: 0.0010
# Epoch 18/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0948 - mae: 0.2657 - val_loss: 0.0870 - val_mae: 0.2438 - learning_rate: 0.0010
# Epoch 19/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0927 - mae: 0.2640 - val_loss: 0.0890 - val_mae: 0.2540 - learning_rate: 0.0010
# Epoch 20/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0925 - mae: 0.2657 - val_loss: 0.0845 - val_mae: 0.2415 - learning_rate: 0.0010
# Epoch 21/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0914 - mae: 0.2637 - val_loss: 0.0857 - val_mae: 0.2477 - learning_rate: 0.0010
# Epoch 22/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0903 - mae: 0.2628 - val_loss: 0.0863 - val_mae: 0.2510 - learning_rate: 0.0010
# Epoch 23/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0908 - mae: 0.2655 - val_loss: 0.0855 - val_mae: 0.2496 - learning_rate: 0.0010
# Epoch 24/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0898 - mae: 0.2645 - val_loss: 0.0812 - val_mae: 0.2404 - learning_rate: 0.0010
# Epoch 25/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0884 - mae: 0.2632 - val_loss: 0.0821 - val_mae: 0.2436 - learning_rate: 0.0010
# Epoch 26/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0890 - mae: 0.2643 - val_loss: 0.0832 - val_mae: 0.2452 - learning_rate: 0.0010
# Epoch 27/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0873 - mae: 0.2608 - val_loss: 0.0810 - val_mae: 0.2443 - learning_rate: 0.0010
# Epoch 28/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0866 - mae: 0.2610 - val_loss: 0.0813 - val_mae: 0.2455 - learning_rate: 0.0010
# Epoch 29/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0865 - mae: 0.2618 - val_loss: 0.0789 - val_mae: 0.2393 - learning_rate: 0.0010
# Epoch 30/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0850 - mae: 0.2582 - val_loss: 0.0780 - val_mae: 0.2379 - learning_rate: 0.0010
# Epoch 31/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0853 - mae: 0.2608 - val_loss: 0.0772 - val_mae: 0.2381 - learning_rate: 0.0010
# Epoch 32/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0848 - mae: 0.2603 - val_loss: 0.0794 - val_mae: 0.2421 - learning_rate: 0.0010
# Epoch 33/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0841 - mae: 0.2585 - val_loss: 0.0770 - val_mae: 0.2364 - learning_rate: 0.0010
# Epoch 34/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0837 - mae: 0.2582 - val_loss: 0.0756 - val_mae: 0.2336 - learning_rate: 0.0010
# Epoch 35/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0849 - mae: 0.2617 - val_loss: 0.0778 - val_mae: 0.2404 - learning_rate: 0.0010
# Epoch 36/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0843 - mae: 0.2608 - val_loss: 0.0757 - val_mae: 0.2366 - learning_rate: 0.0010
# Epoch 37/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0815 - mae: 0.2544 - val_loss: 0.0744 - val_mae: 0.2341 - learning_rate: 0.0010
# Epoch 38/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0815 - mae: 0.2558 - val_loss: 0.0755 - val_mae: 0.2386 - learning_rate: 0.0010
# Epoch 39/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0808 - mae: 0.2544 - val_loss: 0.0713 - val_mae: 0.2262 - learning_rate: 0.0010
# Epoch 40/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0817 - mae: 0.2579 - val_loss: 0.0738 - val_mae: 0.2326 - learning_rate: 0.0010
# Epoch 41/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0817 - mae: 0.2580 - val_loss: 0.0789 - val_mae: 0.2501 - learning_rate: 0.0010
# Epoch 42/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0815 - mae: 0.2576 - val_loss: 0.0784 - val_mae: 0.2504 - learning_rate: 0.0010
# Epoch 43/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0821 - mae: 0.2594 - val_loss: 0.0771 - val_mae: 0.2426 - learning_rate: 0.0010
# Epoch 44/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0804 - mae: 0.2555 - val_loss: 0.0771 - val_mae: 0.2477 - learning_rate: 0.0010
# Epoch 45/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0806 - mae: 0.2564 - val_loss: 0.0730 - val_mae: 0.2373 - learning_rate: 0.0010
# Epoch 46/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0796 - mae: 0.2560 - val_loss: 0.0748 - val_mae: 0.2424 - learning_rate: 0.0010
# Epoch 47/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0792 - mae: 0.2546 - val_loss: 0.0708 - val_mae: 0.2303 - learning_rate: 0.0010
# Epoch 48/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0799 - mae: 0.2566 - val_loss: 0.0716 - val_mae: 0.2320 - learning_rate: 0.0010
# Epoch 49/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0790 - mae: 0.2547 - val_loss: 0.0729 - val_mae: 0.2347 - learning_rate: 0.0010
# Epoch 50/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0791 - mae: 0.2541 - val_loss: 0.0741 - val_mae: 0.2411 - learning_rate: 0.0010
# Epoch 51/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0787 - mae: 0.2543 - val_loss: 0.0710 - val_mae: 0.2322 - learning_rate: 0.0010
# Epoch 52/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0772 - mae: 0.2507 - val_loss: 0.0703 - val_mae: 0.2312 - learning_rate: 0.0010
# Epoch 53/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0774 - mae: 0.2529 - val_loss: 0.0733 - val_mae: 0.2409 - learning_rate: 0.0010
# Epoch 54/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0777 - mae: 0.2529 - val_loss: 0.0751 - val_mae: 0.2455 - learning_rate: 0.0010
# Epoch 55/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0771 - mae: 0.2511 - val_loss: 0.0710 - val_mae: 0.2320 - learning_rate: 0.0010
# Epoch 56/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0782 - mae: 0.2543 - val_loss: 0.0716 - val_mae: 0.2358 - learning_rate: 0.0010
# Epoch 57/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0773 - mae: 0.2527 - val_loss: 0.0711 - val_mae: 0.2336 - learning_rate: 0.0010
# Epoch 58/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0766 - mae: 0.2507 - val_loss: 0.0732 - val_mae: 0.2426 - learning_rate: 0.0010
# Epoch 59/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0761 - mae: 0.2508 - val_loss: 0.0695 - val_mae: 0.2299 - learning_rate: 0.0010
# Epoch 60/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0755 - mae: 0.2503 - val_loss: 0.0710 - val_mae: 0.2340 - learning_rate: 0.0010
# Epoch 61/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0766 - mae: 0.2515 - val_loss: 0.0684 - val_mae: 0.2274 - learning_rate: 0.0010
# Epoch 62/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0749 - mae: 0.2472 - val_loss: 0.0705 - val_mae: 0.2337 - learning_rate: 0.0010
# Epoch 63/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0752 - mae: 0.2490 - val_loss: 0.0703 - val_mae: 0.2326 - learning_rate: 0.0010
# Epoch 64/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0758 - mae: 0.2507 - val_loss: 0.0709 - val_mae: 0.2352 - learning_rate: 0.0010
# Epoch 65/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0763 - mae: 0.2513 - val_loss: 0.0692 - val_mae: 0.2297 - learning_rate: 0.0010
# Epoch 66/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0765 - mae: 0.2522 - val_loss: 0.0692 - val_mae: 0.2312 - learning_rate: 0.0010
# Epoch 67/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0753 - mae: 0.2486 - val_loss: 0.0685 - val_mae: 0.2283 - learning_rate: 0.0010
# Epoch 68/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0755 - mae: 0.2506 - val_loss: 0.0700 - val_mae: 0.2330 - learning_rate: 0.0010
# Epoch 69/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0752 - mae: 0.2493 - val_loss: 0.0696 - val_mae: 0.2321 - learning_rate: 0.0010
# Epoch 70/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0750 - mae: 0.2487 - val_loss: 0.0712 - val_mae: 0.2403 - learning_rate: 0.0010
# Epoch 71/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0751 - mae: 0.2497 - val_loss: 0.0685 - val_mae: 0.2312 - learning_rate: 0.0010
# Epoch 72/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0751 - mae: 0.2501 - val_loss: 0.0702 - val_mae: 0.2373 - learning_rate: 0.0010
# Epoch 73/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0744 - mae: 0.2486 - val_loss: 0.0679 - val_mae: 0.2275 - learning_rate: 0.0010
# Epoch 74/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0744 - mae: 0.2482 - val_loss: 0.0719 - val_mae: 0.2423 - learning_rate: 0.0010
# Epoch 75/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0742 - mae: 0.2482 - val_loss: 0.0672 - val_mae: 0.2264 - learning_rate: 0.0010
# Epoch 76/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0742 - mae: 0.2486 - val_loss: 0.0676 - val_mae: 0.2292 - learning_rate: 0.0010
# Epoch 77/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0748 - mae: 0.2490 - val_loss: 0.0679 - val_mae: 0.2281 - learning_rate: 0.0010
# Epoch 78/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0748 - mae: 0.2490 - val_loss: 0.0677 - val_mae: 0.2296 - learning_rate: 0.0010
# Epoch 79/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0739 - mae: 0.2466 - val_loss: 0.0666 - val_mae: 0.2259 - learning_rate: 0.0010
# Epoch 80/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0736 - mae: 0.2472 - val_loss: 0.0662 - val_mae: 0.2231 - learning_rate: 0.0010
# Epoch 81/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0739 - mae: 0.2479 - val_loss: 0.0677 - val_mae: 0.2302 - learning_rate: 0.0010
# Epoch 82/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0731 - mae: 0.2465 - val_loss: 0.0654 - val_mae: 0.2237 - learning_rate: 0.0010
# Epoch 83/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0732 - mae: 0.2469 - val_loss: 0.0688 - val_mae: 0.2349 - learning_rate: 0.0010
# Epoch 84/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0730 - mae: 0.2458 - val_loss: 0.0667 - val_mae: 0.2278 - learning_rate: 0.0010
# Epoch 85/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0740 - mae: 0.2483 - val_loss: 0.0654 - val_mae: 0.2224 - learning_rate: 0.0010
# Epoch 86/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0748 - mae: 0.2508 - val_loss: 0.0679 - val_mae: 0.2310 - learning_rate: 0.0010
# Epoch 87/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0738 - mae: 0.2483 - val_loss: 0.0662 - val_mae: 0.2245 - learning_rate: 0.0010
# Epoch 88/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0727 - mae: 0.2450 - val_loss: 0.0688 - val_mae: 0.2356 - learning_rate: 0.0010
# Epoch 89/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0727 - mae: 0.2454 - val_loss: 0.0673 - val_mae: 0.2308 - learning_rate: 0.0010
# Epoch 90/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0727 - mae: 0.2454 - val_loss: 0.0678 - val_mae: 0.2312 - learning_rate: 0.0010
# Epoch 91/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0735 - mae: 0.2475 - val_loss: 0.0674 - val_mae: 0.2294 - learning_rate: 0.0010
# Epoch 92/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0721 - mae: 0.2432 - val_loss: 0.0650 - val_mae: 0.2216 - learning_rate: 0.0010
# Epoch 93/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0716 - mae: 0.2424 - val_loss: 0.0668 - val_mae: 0.2270 - learning_rate: 0.0010
# Epoch 94/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0720 - mae: 0.2437 - val_loss: 0.0672 - val_mae: 0.2287 - learning_rate: 0.0010
# Epoch 95/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0730 - mae: 0.2470 - val_loss: 0.0676 - val_mae: 0.2289 - learning_rate: 0.0010
# Epoch 96/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0731 - mae: 0.2465 - val_loss: 0.0665 - val_mae: 0.2270 - learning_rate: 0.0010
# Epoch 97/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0721 - mae: 0.2447 - val_loss: 0.0678 - val_mae: 0.2308 - learning_rate: 0.0010
# Epoch 98/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0729 - mae: 0.2466 - val_loss: 0.0679 - val_mae: 0.2317 - learning_rate: 0.0010
# Epoch 99/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0720 - mae: 0.2447 - val_loss: 0.0654 - val_mae: 0.2241 - learning_rate: 0.0010
# Epoch 100/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0728 - mae: 0.2464 - val_loss: 0.0663 - val_mae: 0.2284 - learning_rate: 0.0010
# Epoch 101/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0725 - mae: 0.2453 - val_loss: 0.0648 - val_mae: 0.2220 - learning_rate: 0.0010
# Epoch 102/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0728 - mae: 0.2469 - val_loss: 0.0663 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 103/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0731 - mae: 0.2477 - val_loss: 0.0654 - val_mae: 0.2243 - learning_rate: 0.0010
# Epoch 104/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0713 - mae: 0.2421 - val_loss: 0.0675 - val_mae: 0.2318 - learning_rate: 0.0010
# Epoch 105/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0722 - mae: 0.2453 - val_loss: 0.0662 - val_mae: 0.2280 - learning_rate: 0.0010
# Epoch 106/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0719 - mae: 0.2439 - val_loss: 0.0659 - val_mae: 0.2269 - learning_rate: 0.0010
# Epoch 107/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0724 - mae: 0.2465 - val_loss: 0.0662 - val_mae: 0.2257 - learning_rate: 0.0010
# Epoch 108/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0714 - mae: 0.2431 - val_loss: 0.0682 - val_mae: 0.2362 - learning_rate: 0.0010
# Epoch 109/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0717 - mae: 0.2445 - val_loss: 0.0658 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 110/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0718 - mae: 0.2450 - val_loss: 0.0652 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 111/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0715 - mae: 0.2444 - val_loss: 0.0660 - val_mae: 0.2280 - learning_rate: 0.0010
# Epoch 112/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0709 - mae: 0.2421 - val_loss: 0.0646 - val_mae: 0.2227 - learning_rate: 0.0010
# Epoch 113/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0714 - mae: 0.2437 - val_loss: 0.0685 - val_mae: 0.2370 - learning_rate: 0.0010
# Epoch 114/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0705 - mae: 0.2411 - val_loss: 0.0664 - val_mae: 0.2288 - learning_rate: 0.0010
# Epoch 115/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0712 - mae: 0.2431 - val_loss: 0.0657 - val_mae: 0.2261 - learning_rate: 0.0010
# Epoch 116/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0710 - mae: 0.2429 - val_loss: 0.0653 - val_mae: 0.2266 - learning_rate: 0.0010
# Epoch 117/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0706 - mae: 0.2412 - val_loss: 0.0636 - val_mae: 0.2208 - learning_rate: 0.0010
# Epoch 118/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0703 - mae: 0.2414 - val_loss: 0.0648 - val_mae: 0.2259 - learning_rate: 0.0010
# Epoch 119/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0711 - mae: 0.2429 - val_loss: 0.0667 - val_mae: 0.2297 - learning_rate: 0.0010
# Epoch 120/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0711 - mae: 0.2434 - val_loss: 0.0671 - val_mae: 0.2318 - learning_rate: 0.0010
# Epoch 121/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0710 - mae: 0.2428 - val_loss: 0.0659 - val_mae: 0.2296 - learning_rate: 0.0010
# Epoch 122/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0708 - mae: 0.2422 - val_loss: 0.0644 - val_mae: 0.2227 - learning_rate: 0.0010
# Epoch 123/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0702 - mae: 0.2415 - val_loss: 0.0650 - val_mae: 0.2253 - learning_rate: 0.0010
# Epoch 124/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0715 - mae: 0.2436 - val_loss: 0.0659 - val_mae: 0.2272 - learning_rate: 0.0010
# Epoch 125/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0704 - mae: 0.2416 - val_loss: 0.0672 - val_mae: 0.2332 - learning_rate: 0.0010
# Epoch 126/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0708 - mae: 0.2427 - val_loss: 0.0709 - val_mae: 0.2425 - learning_rate: 0.0010
# Epoch 127/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0724 - mae: 0.2458 - val_loss: 0.0668 - val_mae: 0.2318 - learning_rate: 0.0010
# Epoch 128/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0716 - mae: 0.2445 - val_loss: 0.0656 - val_mae: 0.2276 - learning_rate: 0.0010
# Epoch 129/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0710 - mae: 0.2438 - val_loss: 0.0687 - val_mae: 0.2378 - learning_rate: 0.0010
# Epoch 130/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0716 - mae: 0.2446 - val_loss: 0.0666 - val_mae: 0.2305 - learning_rate: 0.0010
# Epoch 131/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0708 - mae: 0.2421 - val_loss: 0.0634 - val_mae: 0.2195 - learning_rate: 0.0010
# Epoch 132/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0698 - mae: 0.2402 - val_loss: 0.0653 - val_mae: 0.2267 - learning_rate: 0.0010
# Epoch 133/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0706 - mae: 0.2425 - val_loss: 0.0652 - val_mae: 0.2267 - learning_rate: 0.0010
# Epoch 134/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0695 - mae: 0.2391 - val_loss: 0.0645 - val_mae: 0.2260 - learning_rate: 0.0010
# Epoch 135/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0702 - mae: 0.2410 - val_loss: 0.0644 - val_mae: 0.2244 - learning_rate: 0.0010
# Epoch 136/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0713 - mae: 0.2446 - val_loss: 0.0654 - val_mae: 0.2279 - learning_rate: 0.0010
# Epoch 137/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0692 - mae: 0.2381 - val_loss: 0.0645 - val_mae: 0.2238 - learning_rate: 0.0010
# Epoch 138/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0697 - mae: 0.2399 - val_loss: 0.0655 - val_mae: 0.2263 - learning_rate: 0.0010
# Epoch 139/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0705 - mae: 0.2418 - val_loss: 0.0626 - val_mae: 0.2193 - learning_rate: 0.0010
# Epoch 140/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0706 - mae: 0.2419 - val_loss: 0.0661 - val_mae: 0.2290 - learning_rate: 0.0010
# Epoch 141/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0703 - mae: 0.2415 - val_loss: 0.0659 - val_mae: 0.2291 - learning_rate: 0.0010
# Epoch 142/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0699 - mae: 0.2396 - val_loss: 0.0662 - val_mae: 0.2299 - learning_rate: 0.0010
# Epoch 143/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0702 - mae: 0.2414 - val_loss: 0.0653 - val_mae: 0.2263 - learning_rate: 0.0010
# Epoch 144/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0707 - mae: 0.2428 - val_loss: 0.0661 - val_mae: 0.2279 - learning_rate: 0.0010
# Epoch 145/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0704 - mae: 0.2417 - val_loss: 0.0641 - val_mae: 0.2221 - learning_rate: 0.0010
# Epoch 146/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0702 - mae: 0.2409 - val_loss: 0.0667 - val_mae: 0.2309 - learning_rate: 0.0010
# Epoch 147/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0705 - mae: 0.2414 - val_loss: 0.0643 - val_mae: 0.2234 - learning_rate: 0.0010
# Epoch 148/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0703 - mae: 0.2411 - val_loss: 0.0649 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 149/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0697 - mae: 0.2401 - val_loss: 0.0641 - val_mae: 0.2235 - learning_rate: 0.0010
# Epoch 150/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0692 - mae: 0.2388 - val_loss: 0.0644 - val_mae: 0.2229 - learning_rate: 0.0010
# Epoch 151/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0700 - mae: 0.2403 - val_loss: 0.0661 - val_mae: 0.2294 - learning_rate: 0.0010
# Epoch 152/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0702 - mae: 0.2412 - val_loss: 0.0643 - val_mae: 0.2220 - learning_rate: 0.0010
# Epoch 153/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0706 - mae: 0.2422 - val_loss: 0.0645 - val_mae: 0.2231 - learning_rate: 0.0010
# Epoch 154/1000
# 426/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0701 - mae: 0.2412
# Epoch 154: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0701 - mae: 0.2413 - val_loss: 0.0655 - val_mae: 0.2264 - learning_rate: 0.0010
# Epoch 155/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0629 - mae: 0.2218 - val_loss: 0.0554 - val_mae: 0.2042 - learning_rate: 5.0000e-04
# Epoch 156/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0564 - mae: 0.2105 - val_loss: 0.0529 - val_mae: 0.2010 - learning_rate: 5.0000e-04
# Epoch 157/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0540 - mae: 0.2067 - val_loss: 0.0507 - val_mae: 0.1989 - learning_rate: 5.0000e-04
# Epoch 158/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0527 - mae: 0.2055 - val_loss: 0.0496 - val_mae: 0.1963 - learning_rate: 5.0000e-04
# Epoch 159/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0517 - mae: 0.2050 - val_loss: 0.0495 - val_mae: 0.1988 - learning_rate: 5.0000e-04
# Epoch 160/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0507 - mae: 0.2030 - val_loss: 0.0493 - val_mae: 0.1998 - learning_rate: 5.0000e-04
# Epoch 161/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0494 - mae: 0.2003 - val_loss: 0.0465 - val_mae: 0.1906 - learning_rate: 5.0000e-04
# Epoch 162/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0492 - mae: 0.2005 - val_loss: 0.0491 - val_mae: 0.2006 - learning_rate: 5.0000e-04
# Epoch 163/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0490 - mae: 0.2008 - val_loss: 0.0470 - val_mae: 0.1942 - learning_rate: 5.0000e-04
# Epoch 164/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0489 - mae: 0.2014 - val_loss: 0.0467 - val_mae: 0.1936 - learning_rate: 5.0000e-04
# Epoch 165/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0476 - mae: 0.1983 - val_loss: 0.0472 - val_mae: 0.1964 - learning_rate: 5.0000e-04
# Epoch 166/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0481 - mae: 0.2000 - val_loss: 0.0482 - val_mae: 0.1999 - learning_rate: 5.0000e-04
# Epoch 167/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0479 - mae: 0.1991 - val_loss: 0.0472 - val_mae: 0.1964 - learning_rate: 5.0000e-04
# Epoch 168/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0482 - mae: 0.2006 - val_loss: 0.0459 - val_mae: 0.1922 - learning_rate: 5.0000e-04
# Epoch 169/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0473 - mae: 0.1978 - val_loss: 0.0455 - val_mae: 0.1923 - learning_rate: 5.0000e-04
# Epoch 170/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0476 - mae: 0.1995 - val_loss: 0.0463 - val_mae: 0.1947 - learning_rate: 5.0000e-04
# Epoch 171/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0479 - mae: 0.2003 - val_loss: 0.0473 - val_mae: 0.1987 - learning_rate: 5.0000e-04
# Epoch 172/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0479 - mae: 0.1998 - val_loss: 0.0477 - val_mae: 0.2000 - learning_rate: 5.0000e-04
# Epoch 173/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0479 - mae: 0.1996 - val_loss: 0.0468 - val_mae: 0.1971 - learning_rate: 5.0000e-04
# Epoch 174/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0474 - mae: 0.1984 - val_loss: 0.0471 - val_mae: 0.1986 - learning_rate: 5.0000e-04
# Epoch 175/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0475 - mae: 0.1987 - val_loss: 0.0465 - val_mae: 0.1958 - learning_rate: 5.0000e-04
# Epoch 176/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0473 - mae: 0.1988 - val_loss: 0.0453 - val_mae: 0.1916 - learning_rate: 5.0000e-04
# Epoch 177/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0467 - mae: 0.1975 - val_loss: 0.0463 - val_mae: 0.1953 - learning_rate: 5.0000e-04
# Epoch 178/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0464 - mae: 0.1966 - val_loss: 0.0453 - val_mae: 0.1925 - learning_rate: 5.0000e-04
# Epoch 179/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0473 - mae: 0.1999 - val_loss: 0.0476 - val_mae: 0.2015 - learning_rate: 5.0000e-04
# Epoch 180/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0468 - mae: 0.1975 - val_loss: 0.0461 - val_mae: 0.1950 - learning_rate: 5.0000e-04
# Epoch 181/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0466 - mae: 0.1970 - val_loss: 0.0452 - val_mae: 0.1913 - learning_rate: 5.0000e-04
# Epoch 182/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0467 - mae: 0.1973 - val_loss: 0.0455 - val_mae: 0.1938 - learning_rate: 5.0000e-04
# Epoch 183/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0461 - mae: 0.1959 - val_loss: 0.0457 - val_mae: 0.1939 - learning_rate: 5.0000e-04
# Epoch 184/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0461 - mae: 0.1964 - val_loss: 0.0464 - val_mae: 0.1971 - learning_rate: 5.0000e-04
# Epoch 185/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0459 - mae: 0.1955 - val_loss: 0.0456 - val_mae: 0.1936 - learning_rate: 5.0000e-04
# Epoch 186/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0464 - mae: 0.1962 - val_loss: 0.0462 - val_mae: 0.1949 - learning_rate: 5.0000e-04
# Epoch 187/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0467 - mae: 0.1979 - val_loss: 0.0468 - val_mae: 0.1987 - learning_rate: 5.0000e-04
# Epoch 188/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0463 - mae: 0.1959 - val_loss: 0.0452 - val_mae: 0.1921 - learning_rate: 5.0000e-04
# Epoch 189/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0459 - mae: 0.1944 - val_loss: 0.0445 - val_mae: 0.1894 - learning_rate: 5.0000e-04
# Epoch 190/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0451 - mae: 0.1926 - val_loss: 0.0460 - val_mae: 0.1953 - learning_rate: 5.0000e-04
# Epoch 191/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0461 - mae: 0.1955 - val_loss: 0.0454 - val_mae: 0.1927 - learning_rate: 5.0000e-04
# Epoch 192/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0466 - mae: 0.1974 - val_loss: 0.0459 - val_mae: 0.1942 - learning_rate: 5.0000e-04
# Epoch 193/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0456 - mae: 0.1939 - val_loss: 0.0451 - val_mae: 0.1916 - learning_rate: 5.0000e-04
# Epoch 194/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0458 - mae: 0.1945 - val_loss: 0.0461 - val_mae: 0.1961 - learning_rate: 5.0000e-04
# Epoch 195/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0458 - mae: 0.1950 - val_loss: 0.0462 - val_mae: 0.1966 - learning_rate: 5.0000e-04
# Epoch 196/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0452 - mae: 0.1925 - val_loss: 0.0462 - val_mae: 0.1972 - learning_rate: 5.0000e-04
# Epoch 197/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0471 - mae: 0.1995 - val_loss: 0.0461 - val_mae: 0.1960 - learning_rate: 5.0000e-04
# Epoch 198/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0454 - mae: 0.1939 - val_loss: 0.0455 - val_mae: 0.1937 - learning_rate: 5.0000e-04
# Epoch 199/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0456 - mae: 0.1942 - val_loss: 0.0456 - val_mae: 0.1944 - learning_rate: 5.0000e-04
# Epoch 200/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0461 - mae: 0.1962 - val_loss: 0.0454 - val_mae: 0.1938 - learning_rate: 5.0000e-04
# Epoch 201/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0462 - mae: 0.1957 - val_loss: 0.0460 - val_mae: 0.1954 - learning_rate: 5.0000e-04
# Epoch 202/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0464 - mae: 0.1964 - val_loss: 0.0447 - val_mae: 0.1909 - learning_rate: 5.0000e-04
# Epoch 203/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0452 - mae: 0.1924 - val_loss: 0.0451 - val_mae: 0.1920 - learning_rate: 5.0000e-04
# Epoch 204/1000
# 415/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0451 - mae: 0.1930
# Epoch 204: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0451 - mae: 0.1931 - val_loss: 0.0451 - val_mae: 0.1911 - learning_rate: 5.0000e-04
# Epoch 205/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0421 - mae: 0.1825 - val_loss: 0.0395 - val_mae: 0.1748 - learning_rate: 2.5000e-04
# Epoch 206/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0388 - mae: 0.1739 - val_loss: 0.0399 - val_mae: 0.1789 - learning_rate: 2.5000e-04
# Epoch 207/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0370 - mae: 0.1691 - val_loss: 0.0386 - val_mae: 0.1760 - learning_rate: 2.5000e-04
# Epoch 208/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0362 - mae: 0.1682 - val_loss: 0.0380 - val_mae: 0.1752 - learning_rate: 2.5000e-04
# Epoch 209/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0356 - mae: 0.1675 - val_loss: 0.0369 - val_mae: 0.1731 - learning_rate: 2.5000e-04
# Epoch 210/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0348 - mae: 0.1663 - val_loss: 0.0367 - val_mae: 0.1736 - learning_rate: 2.5000e-04
# Epoch 211/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0347 - mae: 0.1664 - val_loss: 0.0370 - val_mae: 0.1747 - learning_rate: 2.5000e-04
# Epoch 212/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0349 - mae: 0.1683 - val_loss: 0.0370 - val_mae: 0.1768 - learning_rate: 2.5000e-04
# Epoch 213/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0343 - mae: 0.1668 - val_loss: 0.0368 - val_mae: 0.1769 - learning_rate: 2.5000e-04
# Epoch 214/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0340 - mae: 0.1653 - val_loss: 0.0369 - val_mae: 0.1764 - learning_rate: 2.5000e-04
# Epoch 215/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0333 - mae: 0.1635 - val_loss: 0.0359 - val_mae: 0.1738 - learning_rate: 2.5000e-04
# Epoch 216/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0334 - mae: 0.1641 - val_loss: 0.0369 - val_mae: 0.1785 - learning_rate: 2.5000e-04
# Epoch 217/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0332 - mae: 0.1638 - val_loss: 0.0360 - val_mae: 0.1752 - learning_rate: 2.5000e-04
# Epoch 218/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0337 - mae: 0.1666 - val_loss: 0.0354 - val_mae: 0.1727 - learning_rate: 2.5000e-04
# Epoch 219/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0332 - mae: 0.1644 - val_loss: 0.0364 - val_mae: 0.1766 - learning_rate: 2.5000e-04
# Epoch 220/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0332 - mae: 0.1643 - val_loss: 0.0359 - val_mae: 0.1755 - learning_rate: 2.5000e-04
# Epoch 221/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0333 - mae: 0.1659 - val_loss: 0.0356 - val_mae: 0.1740 - learning_rate: 2.5000e-04
# Epoch 222/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0325 - mae: 0.1629 - val_loss: 0.0365 - val_mae: 0.1776 - learning_rate: 2.5000e-04
# Epoch 223/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0322 - mae: 0.1617 - val_loss: 0.0358 - val_mae: 0.1750 - learning_rate: 2.5000e-04
# Epoch 224/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0326 - mae: 0.1630 - val_loss: 0.0352 - val_mae: 0.1734 - learning_rate: 2.5000e-04
# Epoch 225/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0317 - mae: 0.1603 - val_loss: 0.0356 - val_mae: 0.1760 - learning_rate: 2.5000e-04
# Epoch 226/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0326 - mae: 0.1641 - val_loss: 0.0351 - val_mae: 0.1747 - learning_rate: 2.5000e-04
# Epoch 227/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0323 - mae: 0.1633 - val_loss: 0.0353 - val_mae: 0.1741 - learning_rate: 2.5000e-04
# Epoch 228/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0317 - mae: 0.1610 - val_loss: 0.0356 - val_mae: 0.1768 - learning_rate: 2.5000e-04
# Epoch 229/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0320 - mae: 0.1626 - val_loss: 0.0352 - val_mae: 0.1741 - learning_rate: 2.5000e-04
# Epoch 230/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0319 - mae: 0.1622 - val_loss: 0.0352 - val_mae: 0.1751 - learning_rate: 2.5000e-04
# Epoch 231/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0318 - mae: 0.1619 - val_loss: 0.0348 - val_mae: 0.1733 - learning_rate: 2.5000e-04
# Epoch 232/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0320 - mae: 0.1624 - val_loss: 0.0349 - val_mae: 0.1746 - learning_rate: 2.5000e-04
# Epoch 233/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0319 - mae: 0.1621 - val_loss: 0.0354 - val_mae: 0.1761 - learning_rate: 2.5000e-04
# Epoch 234/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0319 - mae: 0.1617 - val_loss: 0.0353 - val_mae: 0.1758 - learning_rate: 2.5000e-04
# Epoch 235/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0316 - mae: 0.1619 - val_loss: 0.0352 - val_mae: 0.1755 - learning_rate: 2.5000e-04
# Epoch 236/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0313 - mae: 0.1600 - val_loss: 0.0352 - val_mae: 0.1752 - learning_rate: 2.5000e-04
# Epoch 237/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0317 - mae: 0.1617 - val_loss: 0.0349 - val_mae: 0.1733 - learning_rate: 2.5000e-04
# Epoch 238/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0308 - mae: 0.1587 - val_loss: 0.0356 - val_mae: 0.1772 - learning_rate: 2.5000e-04
# Epoch 239/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0317 - mae: 0.1621 - val_loss: 0.0353 - val_mae: 0.1758 - learning_rate: 2.5000e-04
# Epoch 240/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0315 - mae: 0.1609 - val_loss: 0.0350 - val_mae: 0.1745 - learning_rate: 2.5000e-04
# Epoch 241/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0314 - mae: 0.1609 - val_loss: 0.0351 - val_mae: 0.1743 - learning_rate: 2.5000e-04
# Epoch 242/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0308 - mae: 0.1587 - val_loss: 0.0349 - val_mae: 0.1750 - learning_rate: 2.5000e-04
# Epoch 243/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0313 - mae: 0.1607 - val_loss: 0.0349 - val_mae: 0.1756 - learning_rate: 2.5000e-04
# Epoch 244/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0316 - mae: 0.1626 - val_loss: 0.0348 - val_mae: 0.1742 - learning_rate: 2.5000e-04
# Epoch 245/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0312 - mae: 0.1603 - val_loss: 0.0351 - val_mae: 0.1755 - learning_rate: 2.5000e-04
# Epoch 246/1000
# 421/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0321 - mae: 0.1637
# Epoch 246: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0321 - mae: 0.1637 - val_loss: 0.0352 - val_mae: 0.1768 - learning_rate: 2.5000e-04
# Epoch 247/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0297 - mae: 0.1545 - val_loss: 0.0325 - val_mae: 0.1665 - learning_rate: 1.2500e-04
# Epoch 248/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0271 - mae: 0.1442 - val_loss: 0.0321 - val_mae: 0.1657 - learning_rate: 1.2500e-04
# Epoch 249/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0265 - mae: 0.1421 - val_loss: 0.0315 - val_mae: 0.1641 - learning_rate: 1.2500e-04
# Epoch 250/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0263 - mae: 0.1424 - val_loss: 0.0316 - val_mae: 0.1647 - learning_rate: 1.2500e-04
# Epoch 251/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0262 - mae: 0.1430 - val_loss: 0.0313 - val_mae: 0.1649 - learning_rate: 1.2500e-04
# Epoch 252/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0259 - mae: 0.1417 - val_loss: 0.0314 - val_mae: 0.1653 - learning_rate: 1.2500e-04
# Epoch 253/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0263 - mae: 0.1440 - val_loss: 0.0311 - val_mae: 0.1649 - learning_rate: 1.2500e-04
# Epoch 254/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0261 - mae: 0.1438 - val_loss: 0.0309 - val_mae: 0.1643 - learning_rate: 1.2500e-04
# Epoch 255/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0250 - mae: 0.1393 - val_loss: 0.0307 - val_mae: 0.1637 - learning_rate: 1.2500e-04
# Epoch 256/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0260 - mae: 0.1441 - val_loss: 0.0308 - val_mae: 0.1648 - learning_rate: 1.2500e-04
# Epoch 257/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0246 - mae: 0.1386 - val_loss: 0.0306 - val_mae: 0.1646 - learning_rate: 1.2500e-04
# Epoch 258/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0248 - mae: 0.1396 - val_loss: 0.0303 - val_mae: 0.1635 - learning_rate: 1.2500e-04
# Epoch 259/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0246 - mae: 0.1392 - val_loss: 0.0307 - val_mae: 0.1654 - learning_rate: 1.2500e-04
# Epoch 260/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0248 - mae: 0.1406 - val_loss: 0.0301 - val_mae: 0.1637 - learning_rate: 1.2500e-04
# Epoch 261/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0246 - mae: 0.1401 - val_loss: 0.0303 - val_mae: 0.1650 - learning_rate: 1.2500e-04
# Epoch 262/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0246 - mae: 0.1400 - val_loss: 0.0307 - val_mae: 0.1660 - learning_rate: 1.2500e-04
# Epoch 263/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0250 - mae: 0.1426 - val_loss: 0.0306 - val_mae: 0.1666 - learning_rate: 1.2500e-04
# Epoch 264/1000
# ...
# Epoch 492/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1036 - val_loss: 0.0235 - val_mae: 0.1498 - learning_rate: 1.9531e-06
# Epoch 493/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0144 - mae: 0.1051 - val_loss: 0.0238 - val_mae: 0.1509 - learning_rate: 1.9531e-06
# Epoch 494/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1020 - val_loss: 0.0238 - val_mae: 0.1514 - learning_rate: 1.9531e-06
# Epoch 495/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0141 - mae: 0.1025 - val_loss: 0.0238 - val_mae: 0.1514 - learning_rate: 1.9531e-06
# Epoch 496/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1019 - val_loss: 0.0238 - val_mae: 0.1511 - learning_rate: 1.9531e-06
# Epoch 497/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1035 - val_loss: 0.0237 - val_mae: 0.1508 - learning_rate: 1.9531e-06
# Epoch 498/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1037 - val_loss: 0.0236 - val_mae: 0.1499 - learning_rate: 1.9531e-06
# Epoch 499/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1039 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 1.9531e-06
# Epoch 500/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1034 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 1.9531e-06
# Epoch 501/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1038 - val_loss: 0.0236 - val_mae: 0.1500 - learning_rate: 1.9531e-06
# Epoch 502/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1024 - val_loss: 0.0235 - val_mae: 0.1496 - learning_rate: 1.9531e-06
# Epoch 503/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1036 - val_loss: 0.0237 - val_mae: 0.1511 - learning_rate: 1.9531e-06
# Epoch 504/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1032 - val_loss: 0.0236 - val_mae: 0.1501 - learning_rate: 1.9531e-06
# Epoch 505/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0147 - mae: 0.1060 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 1.9531e-06
# Epoch 506/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0145 - mae: 0.1046 - val_loss: 0.0237 - val_mae: 0.1511 - learning_rate: 1.9531e-06
# Epoch 507/1000
# 424/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.1009
# Epoch 507: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.1009 - val_loss: 0.0237 - val_mae: 0.1511 - learning_rate: 1.9531e-06
# Epoch 508/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1041 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 9.7656e-07
# Epoch 509/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.1011 - val_loss: 0.0238 - val_mae: 0.1513 - learning_rate: 9.7656e-07
# Epoch 510/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1028 - val_loss: 0.0237 - val_mae: 0.1507 - learning_rate: 9.7656e-07
# Epoch 511/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1034 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 9.7656e-07
# Epoch 512/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1024 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 9.7656e-07
# Epoch 513/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1033 - val_loss: 0.0236 - val_mae: 0.1506 - learning_rate: 9.7656e-07
# Epoch 514/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0141 - mae: 0.1032 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 9.7656e-07
# Epoch 515/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1029 - val_loss: 0.0236 - val_mae: 0.1504 - learning_rate: 9.7656e-07
# Epoch 516/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1036 - val_loss: 0.0237 - val_mae: 0.1507 - learning_rate: 9.7656e-07
# Epoch 517/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1039 - val_loss: 0.0237 - val_mae: 0.1509 - learning_rate: 9.7656e-07
# Epoch 518/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0145 - mae: 0.1045 - val_loss: 0.0236 - val_mae: 0.1504 - learning_rate: 9.7656e-07
# Epoch 519/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1032 - val_loss: 0.0236 - val_mae: 0.1504 - learning_rate: 9.7656e-07
# Epoch 520/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0141 - mae: 0.1030 - val_loss: 0.0237 - val_mae: 0.1509 - learning_rate: 9.7656e-07
# Epoch 521/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1038 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 9.7656e-07
# Epoch 522/1000
# 421/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - mae: 0.1021
# Epoch 522: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1022 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 9.7656e-07
# Epoch 523/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1041 - val_loss: 0.0235 - val_mae: 0.1495 - learning_rate: 4.8828e-07
# Epoch 524/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1033 - val_loss: 0.0236 - val_mae: 0.1506 - learning_rate: 4.8828e-07
# Epoch 525/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0141 - mae: 0.1025 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 4.8828e-07
# Epoch 526/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1022 - val_loss: 0.0237 - val_mae: 0.1506 - learning_rate: 4.8828e-07
# Epoch 527/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1031 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 4.8828e-07
# Epoch 528/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0141 - mae: 0.1024 - val_loss: 0.0238 - val_mae: 0.1513 - learning_rate: 4.8828e-07
# Epoch 529/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1036 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 4.8828e-07
# Epoch 530/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0146 - mae: 0.1061 - val_loss: 0.0236 - val_mae: 0.1507 - learning_rate: 4.8828e-07
# Epoch 531/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1040 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 4.8828e-07
# Epoch 532/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1033 - val_loss: 0.0234 - val_mae: 0.1495 - learning_rate: 4.8828e-07
# Epoch 533/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1023 - val_loss: 0.0237 - val_mae: 0.1510 - learning_rate: 4.8828e-07
# Epoch 534/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1025 - val_loss: 0.0235 - val_mae: 0.1498 - learning_rate: 4.8828e-07
# Epoch 535/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1015 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 4.8828e-07
# Epoch 536/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1019 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 4.8828e-07
# Epoch 537/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1029 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 4.8828e-07
# Epoch 538/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1027 - val_loss: 0.0237 - val_mae: 0.1507 - learning_rate: 4.8828e-07
# Epoch 539/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1022 - val_loss: 0.0237 - val_mae: 0.1509 - learning_rate: 4.8828e-07
# Epoch 540/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1047 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 4.8828e-07
# Epoch 541/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1016 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 4.8828e-07
# Epoch 542/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0138 - mae: 0.1014 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 4.8828e-07
# Epoch 543/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1026 - val_loss: 0.0234 - val_mae: 0.1494 - learning_rate: 4.8828e-07
# Epoch 544/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0138 - mae: 0.1011 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 4.8828e-07
# Epoch 545/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1016 - val_loss: 0.0236 - val_mae: 0.1503 - learning_rate: 4.8828e-07
# Epoch 546/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1024 - val_loss: 0.0238 - val_mae: 0.1512 - learning_rate: 4.8828e-07
# Epoch 547/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - mae: 0.1035
# Epoch 547: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1035 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 4.8828e-07
# Epoch 548/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1041 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 2.4414e-07
# Epoch 549/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0145 - mae: 0.1052 - val_loss: 0.0237 - val_mae: 0.1509 - learning_rate: 2.4414e-07
# Epoch 550/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mae: 0.1034 - val_loss: 0.0236 - val_mae: 0.1501 - learning_rate: 2.4414e-07
# Epoch 551/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1022 - val_loss: 0.0236 - val_mae: 0.1503 - learning_rate: 2.4414e-07
# Epoch 552/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1035 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 2.4414e-07
# Epoch 553/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1032 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 2.4414e-07
# Epoch 554/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1026 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 2.4414e-07
# Epoch 555/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.1042 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 2.4414e-07
# Epoch 556/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1028 - val_loss: 0.0237 - val_mae: 0.1507 - learning_rate: 2.4414e-07
# Epoch 557/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0143 - mae: 0.1037 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 2.4414e-07
# Epoch 558/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0144 - mae: 0.1047 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 2.4414e-07
# Epoch 559/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1036 - val_loss: 0.0236 - val_mae: 0.1506 - learning_rate: 2.4414e-07
# Epoch 560/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0139 - mae: 0.1018 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 2.4414e-07
# Epoch 561/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1021 - val_loss: 0.0236 - val_mae: 0.1504 - learning_rate: 2.4414e-07
# Epoch 562/1000
# 427/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - mae: 0.1021
# Epoch 562: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1021 - val_loss: 0.0234 - val_mae: 0.1496 - learning_rate: 2.4414e-07
# Epoch 563/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1036 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 1.2207e-07
# Epoch 564/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1030 - val_loss: 0.0236 - val_mae: 0.1503 - learning_rate: 1.2207e-07
# Epoch 565/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1026 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 1.2207e-07
# Epoch 566/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1021 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 1.2207e-07
# Epoch 567/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1025 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 1.2207e-07
# Epoch 568/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1039 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 1.2207e-07
# Epoch 569/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1027 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 1.2207e-07
# Epoch 570/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0142 - mae: 0.1035 - val_loss: 0.0237 - val_mae: 0.1512 - learning_rate: 1.2207e-07
# Epoch 571/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1038 - val_loss: 0.0236 - val_mae: 0.1505 - learning_rate: 1.2207e-07
# Epoch 572/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.1006 - val_loss: 0.0237 - val_mae: 0.1511 - learning_rate: 1.2207e-07
# Epoch 573/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0143 - mae: 0.1038 - val_loss: 0.0237 - val_mae: 0.1510 - learning_rate: 1.2207e-07
# Epoch 574/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1014 - val_loss: 0.0236 - val_mae: 0.1503 - learning_rate: 1.2207e-07
# Epoch 575/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - mae: 0.1028 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 1.2207e-07
# Epoch 576/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.1015 - val_loss: 0.0235 - val_mae: 0.1500 - learning_rate: 1.2207e-07
# Epoch 577/1000
# 423/428 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - mae: 0.1016
# Epoch 577: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1016 - val_loss: 0.0238 - val_mae: 0.1513 - learning_rate: 1.2207e-07
# Epoch 578/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1019 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 6.1035e-08
# Epoch 579/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0140 - mae: 0.1022 - val_loss: 0.0236 - val_mae: 0.1502 - learning_rate: 6.1035e-08
# Epoch 580/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0140 - mae: 0.1019 - val_loss: 0.0235 - val_mae: 0.1501 - learning_rate: 6.1035e-08
# Epoch 581/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0138 - mae: 0.1004 - val_loss: 0.0237 - val_mae: 0.1507 - learning_rate: 6.1035e-08
# Epoch 582/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - mae: 0.1013 - val_loss: 0.0235 - val_mae: 0.1499 - learning_rate: 6.1035e-08
# Epoch 583/1000
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0145 - mae: 0.1050 - val_loss: 0.0235 - val_mae: 0.1497 - learning_rate: 6.1035e-08
#
# >>> 6. Final Evaluation...
# 2026-03-02 11:50:53.009759: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 1323449600 exceeds 10% of free system memory.
# 2026-03-02 11:50:54.563978: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:50:54.564023: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-02 11:50:56.323075: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_47', 16 bytes spill stores, 16 bytes spill loads
#
# 2026-03-02 11:50:59.471069: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_60', 24 bytes spill stores, 24 bytes spill loads
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step
#     Test Correlation MAE: 45.2170 mHa
#     Model saved to deployment_objects/NN_H110_DeltaHF.keras
